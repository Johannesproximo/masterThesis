# %% [markdown]
# # Notebook overview
# Generates image embeddings from resized low-resolution (trap) images using DINOv2 (timm), saves them as .pt files, and updates the corresponding CSV files.
#
# - Loads a pretrained DINOv2 model and preprocessing pipeline
# - Loads resized low split CSVs and adds tracking columns for embeddings
# - Copies available embeddings from a cache when present
# - Creates missing embeddings in parallel (ThreadPoolExecutor) and saves .pt files
# - Saves updated CSVs;
#
# The notebook was exported as a Python script and run in a console using Tmux to execute it.

# %% [markdown]
# ## Modul Importe

# %%
import pandas as pd
import timm
import torch

import os
import shutil
from typing import Optional
from PIL import Image

from concurrent.futures import ThreadPoolExecutor, as_completed
import subprocess

# %%
# Number of Threads
MAX_WORKERS = 18

# Folder with CSV files (train, test, val)
CSV_SOURCE_FOLDER_PATH = r'/home/jleick/masterArbeitProjekt/final_release/data/datasets/created'
if not os.path.exists(CSV_SOURCE_FOLDER_PATH):
    raise FileNotFoundError(f"Folder does not exist: {CSV_SOURCE_FOLDER_PATH}")

# Folder to save adapted CSV files (train, test, val)
CSV_DESTINATION_FOLDER_PATH = r'/home/jleick/masterArbeitProjekt/final_release/data/datasets/created/embedding_resized'
if not os.path.exists(CSV_DESTINATION_FOLDER_PATH):
    raise FileNotFoundError(f"Folder does not exist: {CSV_DESTINATION_FOLDER_PATH}")

# Folder with downloaded images
IMAGE_FOLDER_PATH = r'/home/jleick/masterArbeitProjekt/final_release/data/images/adapted/resized/low'
if not os.path.exists(IMAGE_FOLDER_PATH):
    raise FileNotFoundError(f"Folder does not exist: {IMAGE_FOLDER_PATH}")

# Folder to save the embeddings of images
DESTINATION_PATH = r'/home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low'

# Cache folder for available embeddings
# CACHE = r'/home/jleick/masterArbeitProjekt/data/ami_embedding/ami_gbif/gbif_fine_grained(dataset_split)'
CACHE = r'/home/'

# %%
### Select csv files in given folder Path

def select_files(csv_source_folder_path: str):
    folder_contains = os.listdir(csv_source_folder_path)
    folder_filtered = [] 
    # Filter all relevant files
    for filename in folder_contains:
        ### adapt conditions for specific csv files in folder
        if ('low' in filename): # and 'val' in filename):
            folder_filtered.append(filename)

    return folder_filtered

#call funktion
selected_csv_files = select_files(CSV_SOURCE_FOLDER_PATH)

# Print all selected files
for folder_name in selected_csv_files:
    print(folder_name)

# DUBLICATED CODE (CODE EXIST IN OTHER FILE TOO)
# Out:
# low_ood_test.csv
# low_id_test.csv

# %%
### Load CSV data into Pandas DataFrame


def load_data(data_path: str, nrows: Optional[int] = None):
    # Load data into Pandas DataFrame
    df = pd.read_csv(data_path, sep=",", header="infer", nrows=nrows, index_col=0)
    df.reset_index(drop=True,inplace=True)
    # print(f'{df.shape} - Shape of: {data_path.split("/")[-1]}')

    # Check if df contains duplicated URLs
    if not df["identifier"].is_unique:
        duplicates = df["identifier"].duplicated(keep=False).sum()
        print(f"Duplicate: {duplicates} are included in identifier")
        raise Exception('Duplicates are included in identifier') # assert url_list.is_unique

    ### rename file_name sufix to .png
    df["identifier"] = df["identifier"].str.replace(".pt", ".png", regex=False)
    ### rename col_name to image_path
    df = df.rename(columns={"identifier": "image_path"})

    if 'image_path' not in df.columns:
        raise ValueError(f"'image_path' column not found in {dataset_path}")

    return df


### Test function
# test_path = os.path.join(CSV_SOURCE_FOLDER_PATH, selected_csv_files[1])
# data_temp = load_data(test_path, 5)
# data_temp

### DUBLICATED CODE (CODE EXIST IN OTHER FILE TOO)

# %%
### add column to track existing tensors 'tensor_created'


def add_embedding_column_to_df(df: pd.DataFrame):

    column_name_embedding = "embedding_created"
    if column_name_embedding not in df.columns:
        df[column_name_embedding] = False
        print(f'>>> {df.shape} - Added column: {column_name_embedding}')

    column_name_embedding_fail = 'embedding_created_fail'
    if column_name_embedding_fail not in df.columns:
        df[column_name_embedding_fail] = 'NaN'
        print(f'>>> {df.shape} - Added column: {column_name_embedding_fail}')
    
    return column_name_embedding, column_name_embedding_fail


### Test function
# column_name_embedding = add_embedding_column_to_df(data_temp)
# print( f'return: {column_name_embedding}' )
# data_temp

# %%
### Load the model
dinov2_vits14 = timm.create_model("vit_small_patch14_dinov2.lvd142m", pretrained=True)
dinov2_vits14.eval()

### Set device (NICHT GETESTET)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on device {device}.")

dinov2_vits14.to(device)

### Load preprocessing pipeline
data_cfg = timm.data.resolve_data_config(dinov2_vits14.pretrained_cfg)
transform = timm.data.create_transform(**data_cfg)

type(dinov2_vits14)

### transform settings
# dinov2_vits14.pretrained_cfg
data_cfg # is it usefull to do normalisation and if yes on default values
# Out:
# Training on device cuda.
# {'input_size': (3, 518, 518),
#  'interpolation': 'bicubic',
#  'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),
#  'crop_pct': 1.0,
#  'crop_mode': 'center'}

# %%
### copy availables images from cache to destination


def change_file_extension_to_pt(file_path: str):
    base, ext = os.path.splitext(file_path)
    return base + ".pt"


def copy_availabe_embeddings(
    df: pd.DataFrame, source_dir: str, destination_dir: str, column_name_embedding: str, column_name_embedding_fail: str
):
    for index, image_pfad in df["image_path"].items():
        tensor_pfad = change_file_extension_to_pt(image_pfad)
        source_path = os.path.join(source_dir, tensor_pfad)

        # check if image embedding in cache exists
        if os.path.exists(source_path):
            try:
                destination_path = os.path.join(destination_dir, tensor_pfad)

                # check if image embedding in destination already exists
                if not os.path.exists(destination_path):
                    os.makedirs(os.path.dirname(destination_path), exist_ok=True)
                    shutil.copyfile(source_path, destination_path)

                    df.at[index, column_name_embedding] = True
                    df.at[index, column_name_embedding_fail] = "no error"
                    print(f"Tensor (at index: {index}) found and copied: {destination_path}")
                else:
                    df.at[index, column_name_embedding] = True
                    df.at[index, column_name_embedding_fail] = "no error"
                    print(f"Tensor (at index: {index}) exist already - No copy required : {image_pfad}")
            except Exception as e:
                print(f"Error Image (at index: {index}) copying image {destination_path}: {e}")
        else:
            print(f"Tensor (at index: {index}) not found: {source_path}")


### Test function
# destination_path_update = DESTINATION_PATH + '/' + selected_image_folders[0]
# copy_availabe_embeddings(data_temp, CACHE, destination_path_update, column_name_embedding)

# %%
### Create Tensor for images not exist yet
# Embeddings and tensor are used synonymously

def image_to_tensor(
    index: int,
    df: pd.DataFrame,
    model: object,
    transform: object,
    source_dir: str,
    destination_dir: str,
    column_name_embedding: str,
    column_name_embedding_fail: str
):

    if not df.at[index, column_name_embedding]:
        try:
            # load image from source
            image_path = df.at[index, "image_path"]
            source_path = os.path.join(source_dir, image_path)
            image = Image.open(source_path).convert("RGB")

            # transform image to tensor (embeddings)
            image_transformed = transform(image)
            image_transformed = image_transformed.unsqueeze(0).to(device)
            tensor = model(image_transformed)

            # save tensor to destination
            tensor_path = change_file_extension_to_pt(image_path)
            destination_path = os.path.join(destination_dir, tensor_path)
            os.makedirs(os.path.dirname(destination_path), exist_ok=True)
            torch.save(tensor, destination_path)

            # save info into dataFrame
            df.at[index, column_name_embedding] = True
            df.at[index, column_name_embedding_fail] = "no error"
            print(f"Tensor (at index: {index}) created and saved: {destination_path}")
        except Exception as e:
            df.at[index, column_name_embedding_fail] = f'{e}'
            print(f"Error Image (at index: {index}) by creating tensor {image_path}: {e}")
    else:
        print(f"Tensor (at index: {index}) already exists: {df.at[index, 'image_path']}")


### Test function
# destination_path_update = DESTINATION_PATH + '/' + selected_image_folders[0]
# source_dir_update = IMAGE_FOLDER_PATH + '/' + selected_image_folders[0]
# image_to_tensor(0, data_temp, dinov2_vits14, transform, source_dir_update, destination_path_update, "tensor_created")

# %%
### Execute download_image function with ThreadPoolExecutor

def image_to_tensor_with_executorpool(
    max_workers: int,
    image_to_tensor: callable,
    df: pd.DataFrame,
    model: object,
    transform: object,
    source_dir: str,
    destination_dir: str,
    column_name_embedding: str,
    column_name_embedding_fail: str
):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        for index in df.index:
            if len(futures) > 50:
                for future in as_completed(futures):
                    try:
                        future.result()
                    except Exception as e:
                        print(f"Error while retreving result from future: {e}")
                futures = []

            future = executor.submit(
                image_to_tensor,
                index,
                df,
                model,
                transform,
                source_dir,
                destination_dir,
                column_name_embedding,
                column_name_embedding_fail
            )
            futures.append(future)


### Test function
# destination_path_update = DESTINATION_PATH + '/' + selected_image_folders[0]
# source_dir_update = IMAGE_FOLDER_PATH + '/' + selected_image_folders[0]
# image_to_tensor_with_executorpool(MAX_WORKERS, image_to_tensor, data_temp, dinov2_vits14, transform, source_dir_update, destination_path_update, column_name_embedding)

# %%
### RUN - call functions to process file
def process_file(
    csv_load_dir: str,
    csv_save_dir: str,
    model: object,
    transform: object,
    image_source_dir: str,
    embedding_destination_dir: str,
    CACHE: str,
    MAX_WORKERS: int,
):
    print(f"Processing CSV file from: {csv_load_dir}")
    print(f"Saving CSV file to: {csv_save_dir}")
    print(f"Source folder: {image_source_dir}")
    print(f"Destination folder: {embedding_destination_dir}")
    print(f"Cache folder: {CACHE}")
    print("--------------------------------------")

    # process file
    print(">>> Load data and add column to track existing tensors")
    df = load_data(csv_load_dir)
    column_name_embeddings, column_name_embedding_fail = add_embedding_column_to_df(df)

    print(">>> Starting copy availabe tensors from cache to destination")
    copy_availabe_embeddings(
        df, CACHE, embedding_destination_dir, column_name_embeddings, column_name_embedding_fail
    )

    print(f">>> Starting creating tensors with {MAX_WORKERS} workers")
    image_to_tensor_with_executorpool(
        MAX_WORKERS,
        image_to_tensor,
        df,
        model,
        transform,
        image_source_dir,
        embedding_destination_dir,
        column_name_embeddings,
        column_name_embedding_fail
    )

    print(f">>> Save updated Dataframe to: {csv_save_dir}")
    df.to_csv(csv_save_dir, na_rep="NULL", index=False)

    # print(">>> Copy files to cache if not available")
    # subprocess.run(f'rsync -av --ignore-existing {embedding_destination_dir + "/"} {CACHE}', shell=True, check=True)
    # !rsync -av --ignore-existing {DESTINATION} {CACHE}

    print(f">>> FINISH Process: {csv_filename}\n\n")


### call funktions

# matching selected csv file with image folders
for csv_filename in selected_csv_files:

    csv_load_path = os.path.join(CSV_SOURCE_FOLDER_PATH, csv_filename)
    csv_save_path = os.path.join(CSV_DESTINATION_FOLDER_PATH, csv_filename)

    process_file(
        csv_load_path,
        csv_save_path,
        dinov2_vits14,
        transform,
        IMAGE_FOLDER_PATH,
        DESTINATION_PATH,
        CACHE,
        MAX_WORKERS,
    )
# Out:
# Processing CSV file from: /home/jleick/masterArbeitProjekt/final_release/data/datasets/created/low_ood_test.csv
# Saving CSV file to: /home/jleick/masterArbeitProjekt/final_release/data/datasets/created/embedding_resized/low_ood_test.csv
# Source folder: /home/jleick/masterArbeitProjekt/final_release/data/images/adapted/resized/low
# Destination folder: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low
# Cache folder: /home/
# --------------------------------------
# >>> Load data and add column to track existing tensors
# >>> (698, 8) - Added column: embedding_created
# >>> (698, 9) - Added column: embedding_created_fail
# >>> Starting copy availabe tensors from cache to destination
# Tensor (at index: 0) not found: /home/fgrained-26.pt
# Tensor (at index: 1) not found: /home/fgrained-29.pt
# Tensor (at index: 2) not found: /home/fgrained-3340.pt
# Tensor (at index: 3) not found: /home/fgrained-8222.pt
# Tensor (at index: 4) not found: /home/fgrained-12171.pt
# Tensor (at index: 5) not found: /home/fgrained-12180.pt
# Tensor (at index: 6) not found: /home/fgrained-12204.pt
# Tensor (at index: 7) not found: /home/fgrained-12555.pt
# Tensor (at index: 8) not found: /home/fgrained-12596.pt
# Tensor (at index: 9) not found: /home/fgrained-12773.pt
# Tensor (at index: 10) not found: /home/fgrained-49.pt
# Tensor (at index: 11) not found: /home/fgrained-5270.pt
# Tensor (at index: 12) not found: /home/fgrained-5359.pt
# Tensor (at index: 13) not found: /home/fgrained-5375.pt
# Tensor (at index: 14) not found: /home/fgrained-5858.pt
# Tensor (at index: 15) not found: /home/fgrained-5882.pt
# Tensor (at index: 16) not found: /home/fgrained-6079.pt
# Tensor (at index: 17) not found: /home/fgrained-6094.pt
# Tensor (at index: 18) not found: /home/fgrained-6106.pt
# Tensor (at index: 19) not found: /home/fgrained-6468.pt
# Tensor (at index: 20) not found: /home/fgrained-6633.pt
# Tensor (at index: 21) not found: /home/fgrained-13622.pt
# Tensor (at index: 22) not found: /home/fgrained-13803.pt
# Tensor (at index: 23) not found: /home/fgrained-14081.pt
# Tensor (at index: 24) not found: /home/fgrained-5975.pt
# Tensor (at index: 25) not found: /home/fgrained-456.pt
# Tensor (at index: 26) not found: /home/fgrained-5200.pt
# Tensor (at index: 27) not found: /home/fgrained-13022.pt
# Tensor (at index: 28) not found: /home/fgrained-5333.pt
# Tensor (at index: 29) not found: /home/fgrained-5796.pt
# Tensor (at index: 30) not found: /home/fgrained-6280.pt
# Tensor (at index: 31) not found: /home/fgrained-5585.pt
# Tensor (at index: 32) not found: /home/fgrained-723.pt
# Tensor (at index: 33) not found: /home/fgrained-2626.pt
# Tensor (at index: 34) not found: /home/fgrained-5739.pt
# Tensor (at index: 35) not found: /home/fgrained-13635.pt
# Tensor (at index: 36) not found: /home/fgrained-13652.pt
# Tensor (at index: 37) not found: /home/fgrained-13620.pt
# Tensor (at index: 38) not found: /home/fgrained-5413.pt
# Tensor (at index: 39) not found: /home/fgrained-5169.pt
# Tensor (at index: 40) not found: /home/fgrained-6214.pt
# Tensor (at index: 41) not found: /home/fgrained-994.pt
# Tensor (at index: 42) not found: /home/fgrained-5237.pt
# Tensor (at index: 43) not found: /home/fgrained-1143.pt
# Tensor (at index: 44) not found: /home/fgrained-13682.pt
# Tensor (at index: 45) not found: /home/fgrained-1026.pt
# Tensor (at index: 46) not found: /home/fgrained-5346.pt
# Tensor (at index: 47) not found: /home/fgrained-5487.pt
# Tensor (at index: 48) not found: /home/fgrained-2679.pt
# Tensor (at index: 49) not found: /home/fgrained-5362.pt
# Tensor (at index: 50) not found: /home/fgrained-13767.pt
# Tensor (at index: 51) not found: /home/fgrained-13706.pt
# Tensor (at index: 52) not found: /home/fgrained-759.pt
# Tensor (at index: 53) not found: /home/fgrained-5578.pt
# Tensor (at index: 54) not found: /home/fgrained-5777.pt
# Tensor (at index: 55) not found: /home/fgrained-5239.pt
# Tensor (at index: 56) not found: /home/fgrained-5459.pt
# Tensor (at index: 57) not found: /home/fgrained-13092.pt
# Tensor (at index: 58) not found: /home/fgrained-13638.pt
# Tensor (at index: 59) not found: /home/fgrained-2442.pt
# Tensor (at index: 60) not found: /home/fgrained-5216.pt
# Tensor (at index: 61) not found: /home/fgrained-1013.pt
# Tensor (at index: 62) not found: /home/fgrained-5190.pt
# Tensor (at index: 63) not found: /home/fgrained-5417.pt
# Tensor (at index: 64) not found: /home/fgrained-5990.pt
# Tensor (at index: 65) not found: /home/fgrained-5652.pt
# Tensor (at index: 66) not found: /home/fgrained-13694.pt
# Tensor (at index: 67) not found: /home/fgrained-5756.pt
# Tensor (at index: 68) not found: /home/fgrained-4867.pt
# Tensor (at index: 69) not found: /home/fgrained-5143.pt
# Tensor (at index: 70) not found: /home/fgrained-997.pt
# Tensor (at index: 71) not found: /home/fgrained-5147.pt
# Tensor (at index: 72) not found: /home/fgrained-13050.pt
# Tensor (at index: 73) not found: /home/fgrained-6249.pt
# Tensor (at index: 74) not found: /home/fgrained-5663.pt
# Tensor (at index: 75) not found: /home/fgrained-3101.pt
# Tensor (at index: 76) not found: /home/fgrained-5445.pt
# Tensor (at index: 77) not found: /home/fgrained-5214.pt
# Tensor (at index: 78) not found: /home/fgrained-5047.pt
# Tensor (at index: 79) not found: /home/fgrained-13625.pt
# Tensor (at index: 80) not found: /home/fgrained-5258.pt
# Tensor (at index: 81) not found: /home/fgrained-5427.pt
# Tensor (at index: 82) not found: /home/fgrained-5370.pt
# Tensor (at index: 83) not found: /home/fgrained-5075.pt
# Tensor (at index: 84) not found: /home/fgrained-5250.pt
# Tensor (at index: 85) not found: /home/fgrained-5627.pt
# Tensor (at index: 86) not found: /home/fgrained-13727.pt
# Tensor (at index: 87) not found: /home/fgrained-5369.pt
# Tensor (at index: 88) not found: /home/fgrained-13641.pt
# Tensor (at index: 89) not found: /home/fgrained-5446.pt
# Tensor (at index: 90) not found: /home/fgrained-5306.pt
# Tensor (at index: 91) not found: /home/fgrained-5688.pt
# Tensor (at index: 92) not found: /home/fgrained-5186.pt
# Tensor (at index: 93) not found: /home/fgrained-5329.pt
# Tensor (at index: 94) not found: /home/fgrained-5517.pt
# Tensor (at index: 95) not found: /home/fgrained-5174.pt
# Tensor (at index: 96) not found: /home/fgrained-5436.pt
# Tensor (at index: 97) not found: /home/fgrained-5307.pt
# Tensor (at index: 98) not found: /home/fgrained-5330.pt
# Tensor (at index: 99) not found: /home/fgrained-13713.pt
# Tensor (at index: 100) not found: /home/fgrained-5325.pt
# Tensor (at index: 101) not found: /home/fgrained-13699.pt
# Tensor (at index: 102) not found: /home/fgrained-5224.pt
# Tensor (at index: 103) not found: /home/fgrained-2617.pt
# Tensor (at index: 104) not found: /home/fgrained-5619.pt
# Tensor (at index: 105) not found: /home/fgrained-5212.pt
# Tensor (at index: 106) not found: /home/fgrained-5316.pt
# Tensor (at index: 107) not found: /home/fgrained-424.pt
# Tensor (at index: 108) not found: /home/fgrained-5050.pt
# Tensor (at index: 109) not found: /home/fgrained-5389.pt
# Tensor (at index: 110) not found: /home/fgrained-5505.pt
# Tensor (at index: 111) not found: /home/fgrained-5559.pt
# Tensor (at index: 112) not found: /home/fgrained-5142.pt
# Tensor (at index: 113) not found: /home/fgrained-5797.pt
# Tensor (at index: 114) not found: /home/fgrained-5215.pt
# Tensor (at index: 115) not found: /home/fgrained-13621.pt
# Tensor (at index: 116) not found: /home/fgrained-13689.pt
# Tensor (at index: 117) not found: /home/fgrained-2639.pt
# Tensor (at index: 118) not found: /home/fgrained-779.pt
# Tensor (at index: 119) not found: /home/fgrained-2796.pt
# Tensor (at index: 120) not found: /home/fgrained-2533.pt
# Tensor (at index: 121) not found: /home/fgrained-4818.pt
# Tensor (at index: 122) not found: /home/fgrained-5321.pt
# Tensor (at index: 123) not found: /home/fgrained-1057.pt
# Tensor (at index: 124) not found: /home/fgrained-421.pt
# Tensor (at index: 125) not found: /home/fgrained-2562.pt
# Tensor (at index: 126) not found: /home/fgrained-533.pt
# Tensor (at index: 127) not found: /home/fgrained-1001.pt
# Tensor (at index: 128) not found: /home/fgrained-497.pt
# Tensor (at index: 129) not found: /home/fgrained-2508.pt
# Tensor (at index: 130) not found: /home/fgrained-2470.pt
# Tensor (at index: 131) not found: /home/fgrained-953.pt
# Tensor (at index: 132) not found: /home/fgrained-1046.pt
# Tensor (at index: 133) not found: /home/fgrained-1011.pt
# Tensor (at index: 134) not found: /home/fgrained-536.pt
# Tensor (at index: 135) not found: /home/fgrained-221.pt
# Tensor (at index: 136) not found: /home/fgrained-2600.pt
# Tensor (at index: 137) not found: /home/fgrained-630.pt
# Tensor (at index: 138) not found: /home/fgrained-2427.pt
# Tensor (at index: 139) not found: /home/fgrained-639.pt
# Tensor (at index: 140) not found: /home/fgrained-617.pt
# Tensor (at index: 141) not found: /home/fgrained-687.pt
# Tensor (at index: 142) not found: /home/fgrained-537.pt
# Tensor (at index: 143) not found: /home/fgrained-2454.pt
# Tensor (at index: 144) not found: /home/fgrained-609.pt
# Tensor (at index: 145) not found: /home/fgrained-669.pt
# Tensor (at index: 146) not found: /home/fgrained-2591.pt
# Tensor (at index: 147) not found: /home/fgrained-1015.pt
# Tensor (at index: 148) not found: /home/fgrained-173.pt
# Tensor (at index: 149) not found: /home/fgrained-610.pt
# Tensor (at index: 150) not found: /home/fgrained-2421.pt
# Tensor (at index: 151) not found: /home/fgrained-2648.pt
# Tensor (at index: 152) not found: /home/fgrained-799.pt
# Tensor (at index: 153) not found: /home/fgrained-2640.pt
# Tensor (at index: 154) not found: /home/fgrained-871.pt
# Tensor (at index: 155) not found: /home/fgrained-2527.pt
# Tensor (at index: 156) not found: /home/fgrained-507.pt
# Tensor (at index: 157) not found: /home/fgrained-562.pt
# Tensor (at index: 158) not found: /home/fgrained-2461.pt
# Tensor (at index: 159) not found: /home/fgrained-2483.pt
# Tensor (at index: 160) not found: /home/fgrained-956.pt
# Tensor (at index: 161) not found: /home/fgrained-1181.pt
# Tensor (at index: 162) not found: /home/fgrained-465.pt
# Tensor (at index: 163) not found: /home/fgrained-622.pt
# Tensor (at index: 164) not found: /home/fgrained-434.pt
# Tensor (at index: 165) not found: /home/fgrained-460.pt
# Tensor (at index: 166) not found: /home/fgrained-900.pt
# Tensor (at index: 167) not found: /home/fgrained-955.pt
# Tensor (at index: 168) not found: /home/fgrained-616.pt
# Tensor (at index: 169) not found: /home/fgrained-532.pt
# Tensor (at index: 170) not found: /home/fgrained-2451.pt
# Tensor (at index: 171) not found: /home/fgrained-464.pt
# Tensor (at index: 172) not found: /home/fgrained-591.pt
# Tensor (at index: 173) not found: /home/fgrained-2569.pt
# Tensor (at index: 174) not found: /home/fgrained-577.pt
# Tensor (at index: 175) not found: /home/fgrained-1093.pt
# Tensor (at index: 176) not found: /home/fgrained-1078.pt
# Tensor (at index: 177) not found: /home/fgrained-390.pt
# Tensor (at index: 178) not found: /home/fgrained-608.pt
# Tensor (at index: 179) not found: /home/fgrained-1174.pt
# Tensor (at index: 180) not found: /home/fgrained-177.pt
# Tensor (at index: 181) not found: /home/fgrained-481.pt
# Tensor (at index: 182) not found: /home/fgrained-689.pt
# Tensor (at index: 183) not found: /home/fgrained-952.pt
# Tensor (at index: 184) not found: /home/fgrained-2511.pt
# Tensor (at index: 185) not found: /home/fgrained-2592.pt
# Tensor (at index: 186) not found: /home/fgrained-2467.pt
# Tensor (at index: 187) not found: /home/fgrained-153.pt
# Tensor (at index: 188) not found: /home/fgrained-538.pt
# Tensor (at index: 189) not found: /home/fgrained-2568.pt
# Tensor (at index: 190) not found: /home/fgrained-502.pt
# Tensor (at index: 191) not found: /home/fgrained-1084.pt
# Tensor (at index: 192) not found: /home/fgrained-541.pt
# Tensor (at index: 193) not found: /home/fgrained-2506.pt
# Tensor (at index: 194) not found: /home/fgrained-391.pt
# Tensor (at index: 195) not found: /home/fgrained-419.pt
# Tensor (at index: 196) not found: /home/fgrained-1176.pt
# Tensor (at index: 197) not found: /home/fgrained-2656.pt
# Tensor (at index: 198) not found: /home/fgrained-1132.pt
# Tensor (at index: 199) not found: /home/fgrained-940.pt
# Tensor (at index: 200) not found: /home/fgrained-559.pt
# Tensor (at index: 201) not found: /home/fgrained-612.pt
# Tensor (at index: 202) not found: /home/fgrained-684.pt
# Tensor (at index: 203) not found: /home/fgrained-1144.pt
# Tensor (at index: 204) not found: /home/fgrained-620.pt
# Tensor (at index: 205) not found: /home/fgrained-675.pt
# Tensor (at index: 206) not found: /home/fgrained-939.pt
# Tensor (at index: 207) not found: /home/fgrained-569.pt
# Tensor (at index: 208) not found: /home/fgrained-2577.pt
# Tensor (at index: 209) not found: /home/fgrained-1233.pt
# Tensor (at index: 210) not found: /home/fgrained-432.pt
# Tensor (at index: 211) not found: /home/fgrained-2521.pt
# Tensor (at index: 212) not found: /home/fgrained-962.pt
# Tensor (at index: 213) not found: /home/fgrained-856.pt
# Tensor (at index: 214) not found: /home/fgrained-1105.pt
# Tensor (at index: 215) not found: /home/fgrained-13413.pt
# Tensor (at index: 216) not found: /home/fgrained-686.pt
# Tensor (at index: 217) not found: /home/fgrained-500.pt
# Tensor (at index: 218) not found: /home/fgrained-623.pt
# Tensor (at index: 219) not found: /home/fgrained-385.pt
# Tensor (at index: 220) not found: /home/fgrained-176.pt
# Tensor (at index: 221) not found: /home/fgrained-1033.pt
# Tensor (at index: 222) not found: /home/fgrained-576.pt
# Tensor (at index: 223) not found: /home/fgrained-431.pt
# Tensor (at index: 224) not found: /home/fgrained-703.pt
# Tensor (at index: 225) not found: /home/fgrained-4585.pt
# Tensor (at index: 226) not found: /home/fgrained-11872.pt
# Tensor (at index: 227) not found: /home/fgrained-12202.pt
# Tensor (at index: 228) not found: /home/fgrained-12208.pt
# Tensor (at index: 229) not found: /home/fgrained-12812.pt
# Tensor (at index: 230) not found: /home/fgrained-12977.pt
# Tensor (at index: 231) not found: /home/fgrained-860.pt
# Tensor (at index: 232) not found: /home/fgrained-1069.pt
# Tensor (at index: 233) not found: /home/fgrained-1196.pt
# Tensor (at index: 234) not found: /home/fgrained-1215.pt
# Tensor (at index: 235) not found: /home/fgrained-3158.pt
# Tensor (at index: 236) not found: /home/fgrained-3649.pt
# Tensor (at index: 237) not found: /home/fgrained-4192.pt
# Tensor (at index: 238) not found: /home/fgrained-5964.pt
# Tensor (at index: 239) not found: /home/fgrained-6112.pt
# Tensor (at index: 240) not found: /home/fgrained-12845.pt
# Tensor (at index: 241) not found: /home/fgrained-13133.pt
# Tensor (at index: 242) not found: /home/fgrained-13444.pt
# Tensor (at index: 243) not found: /home/fgrained-13496.pt
# Tensor (at index: 244) not found: /home/fgrained-13505.pt
# Tensor (at index: 245) not found: /home/fgrained-1221.pt
# Tensor (at index: 246) not found: /home/fgrained-2996.pt
# Tensor (at index: 247) not found: /home/fgrained-3043.pt
# Tensor (at index: 248) not found: /home/fgrained-3046.pt
# Tensor (at index: 249) not found: /home/fgrained-3050.pt
# Tensor (at index: 250) not found: /home/fgrained-3056.pt
# Tensor (at index: 251) not found: /home/fgrained-3061.pt
# Tensor (at index: 252) not found: /home/fgrained-3067.pt
# Tensor (at index: 253) not found: /home/fgrained-3073.pt
# Tensor (at index: 254) not found: /home/fgrained-3082.pt
# Tensor (at index: 255) not found: /home/fgrained-3091.pt
# Tensor (at index: 256) not found: /home/fgrained-3126.pt
# Tensor (at index: 257) not found: /home/fgrained-4463.pt
# Tensor (at index: 258) not found: /home/fgrained-6692.pt
# Tensor (at index: 259) not found: /home/fgrained-7260.pt
# Tensor (at index: 260) not found: /home/fgrained-7821.pt
# Tensor (at index: 261) not found: /home/fgrained-7838.pt
# Tensor (at index: 262) not found: /home/fgrained-7865.pt
# Tensor (at index: 263) not found: /home/fgrained-7898.pt
# Tensor (at index: 264) not found: /home/fgrained-7901.pt
# Tensor (at index: 265) not found: /home/fgrained-7902.pt
# Tensor (at index: 266) not found: /home/fgrained-7908.pt
# Tensor (at index: 267) not found: /home/fgrained-7916.pt
# Tensor (at index: 268) not found: /home/fgrained-7918.pt
# Tensor (at index: 269) not found: /home/fgrained-8090.pt
# Tensor (at index: 270) not found: /home/fgrained-8154.pt
# Tensor (at index: 271) not found: /home/fgrained-12757.pt
# Tensor (at index: 272) not found: /home/fgrained-13186.pt
# Tensor (at index: 273) not found: /home/fgrained-13187.pt
# Tensor (at index: 274) not found: /home/fgrained-13192.pt
# Tensor (at index: 275) not found: /home/fgrained-13197.pt
# Tensor (at index: 276) not found: /home/fgrained-13268.pt
# Tensor (at index: 277) not found: /home/fgrained-13518.pt
# Tensor (at index: 278) not found: /home/fgrained-13527.pt
# Tensor (at index: 279) not found: /home/fgrained-13532.pt
# Tensor (at index: 280) not found: /home/fgrained-14021.pt
# Tensor (at index: 281) not found: /home/fgrained-14040.pt
# Tensor (at index: 282) not found: /home/fgrained-14061.pt
# Tensor (at index: 283) not found: /home/fgrained-14067.pt
# Tensor (at index: 284) not found: /home/fgrained-14069.pt
# Tensor (at index: 285) not found: /home/fgrained-14089.pt
# Tensor (at index: 286) not found: /home/fgrained-1839.pt
# Tensor (at index: 287) not found: /home/fgrained-9263.pt
# Tensor (at index: 288) not found: /home/fgrained-9265.pt
# Tensor (at index: 289) not found: /home/fgrained-9268.pt
# Tensor (at index: 290) not found: /home/fgrained-11260.pt
# Tensor (at index: 291) not found: /home/fgrained-11295.pt
# Tensor (at index: 292) not found: /home/fgrained-11531.pt
# Tensor (at index: 293) not found: /home/fgrained-11858.pt
# Tensor (at index: 294) not found: /home/fgrained-11893.pt
# Tensor (at index: 295) not found: /home/fgrained-11927.pt
# Tensor (at index: 296) not found: /home/fgrained-11954.pt
# Tensor (at index: 297) not found: /home/fgrained-12304.pt
# Tensor (at index: 298) not found: /home/fgrained-12510.pt
# Tensor (at index: 299) not found: /home/fgrained-12961.pt
# Tensor (at index: 300) not found: /home/fgrained-3219.pt
# Tensor (at index: 301) not found: /home/fgrained-3231.pt
# Tensor (at index: 302) not found: /home/fgrained-3234.pt
# Tensor (at index: 303) not found: /home/fgrained-3236.pt
# Tensor (at index: 304) not found: /home/fgrained-3237.pt
# Tensor (at index: 305) not found: /home/fgrained-3239.pt
# Tensor (at index: 306) not found: /home/fgrained-3244.pt
# Tensor (at index: 307) not found: /home/fgrained-3245.pt
# Tensor (at index: 308) not found: /home/fgrained-3249.pt
# Tensor (at index: 309) not found: /home/fgrained-3251.pt
# Tensor (at index: 310) not found: /home/fgrained-3258.pt
# Tensor (at index: 311) not found: /home/fgrained-3259.pt
# Tensor (at index: 312) not found: /home/fgrained-3268.pt
# Tensor (at index: 313) not found: /home/fgrained-3269.pt
# Tensor (at index: 314) not found: /home/fgrained-3276.pt
# Tensor (at index: 315) not found: /home/fgrained-3277.pt
# Tensor (at index: 316) not found: /home/fgrained-3283.pt
# Tensor (at index: 317) not found: /home/fgrained-3288.pt
# Tensor (at index: 318) not found: /home/fgrained-3289.pt
# Tensor (at index: 319) not found: /home/fgrained-3290.pt
# Tensor (at index: 320) not found: /home/fgrained-3295.pt
# Tensor (at index: 321) not found: /home/fgrained-3298.pt
# Tensor (at index: 322) not found: /home/fgrained-3352.pt
# Tensor (at index: 323) not found: /home/fgrained-3353.pt
# Tensor (at index: 324) not found: /home/fgrained-3368.pt
# Tensor (at index: 325) not found: /home/fgrained-3369.pt
# Tensor (at index: 326) not found: /home/fgrained-3423.pt
# Tensor (at index: 327) not found: /home/fgrained-3435.pt
# Tensor (at index: 328) not found: /home/fgrained-3445.pt
# Tensor (at index: 329) not found: /home/fgrained-3460.pt
# Tensor (at index: 330) not found: /home/fgrained-3469.pt
# Tensor (at index: 331) not found: /home/fgrained-3481.pt
# Tensor (at index: 332) not found: /home/fgrained-8216.pt
# Tensor (at index: 333) not found: /home/fgrained-8218.pt
# Tensor (at index: 334) not found: /home/fgrained-8221.pt
# Tensor (at index: 335) not found: /home/fgrained-8231.pt
# Tensor (at index: 336) not found: /home/fgrained-8237.pt
# Tensor (at index: 337) not found: /home/fgrained-8246.pt
# Tensor (at index: 338) not found: /home/fgrained-8258.pt
# Tensor (at index: 339) not found: /home/fgrained-8269.pt
# Tensor (at index: 340) not found: /home/fgrained-8305.pt
# Tensor (at index: 341) not found: /home/fgrained-8307.pt
# Tensor (at index: 342) not found: /home/fgrained-8310.pt
# Tensor (at index: 343) not found: /home/fgrained-8311.pt
# Tensor (at index: 344) not found: /home/fgrained-8334.pt
# Tensor (at index: 345) not found: /home/fgrained-8339.pt
# Tensor (at index: 346) not found: /home/fgrained-8343.pt
# Tensor (at index: 347) not found: /home/fgrained-8345.pt
# Tensor (at index: 348) not found: /home/fgrained-8352.pt
# Tensor (at index: 349) not found: /home/fgrained-8356.pt
# Tensor (at index: 350) not found: /home/fgrained-8357.pt
# Tensor (at index: 351) not found: /home/fgrained-8364.pt
# Tensor (at index: 352) not found: /home/fgrained-8372.pt
# Tensor (at index: 353) not found: /home/fgrained-8376.pt
# Tensor (at index: 354) not found: /home/fgrained-8378.pt
# Tensor (at index: 355) not found: /home/fgrained-8382.pt
# Tensor (at index: 356) not found: /home/fgrained-8392.pt
# Tensor (at index: 357) not found: /home/fgrained-8477.pt
# Tensor (at index: 358) not found: /home/fgrained-8485.pt
# Tensor (at index: 359) not found: /home/fgrained-9302.pt
# Tensor (at index: 360) not found: /home/fgrained-9422.pt
# Tensor (at index: 361) not found: /home/fgrained-11353.pt
# Tensor (at index: 362) not found: /home/fgrained-11770.pt
# Tensor (at index: 363) not found: /home/fgrained-11856.pt
# Tensor (at index: 364) not found: /home/fgrained-12455.pt
# Tensor (at index: 365) not found: /home/fgrained-12512.pt
# Tensor (at index: 366) not found: /home/fgrained-12949.pt
# Tensor (at index: 367) not found: /home/fgrained-3318.pt
# Tensor (at index: 368) not found: /home/fgrained-8245.pt
# Tensor (at index: 369) not found: /home/fgrained-8257.pt
# Tensor (at index: 370) not found: /home/fgrained-8272.pt
# Tensor (at index: 371) not found: /home/fgrained-8313.pt
# Tensor (at index: 372) not found: /home/fgrained-8315.pt
# Tensor (at index: 373) not found: /home/fgrained-8322.pt
# Tensor (at index: 374) not found: /home/fgrained-11265.pt
# Tensor (at index: 375) not found: /home/fgrained-12604.pt
# Tensor (at index: 376) not found: /home/fgrained-3468.pt
# Tensor (at index: 377) not found: /home/fgrained-8852.pt
# Tensor (at index: 378) not found: /home/fgrained-8855.pt
# Tensor (at index: 379) not found: /home/fgrained-8862.pt
# Tensor (at index: 380) not found: /home/fgrained-9301.pt
# Tensor (at index: 381) not found: /home/fgrained-9950.pt
# Tensor (at index: 382) not found: /home/fgrained-10094.pt
# Tensor (at index: 383) not found: /home/fgrained-3480.pt
# Tensor (at index: 384) not found: /home/fgrained-8497.pt
# Tensor (at index: 385) not found: /home/fgrained-8500.pt
# Tensor (at index: 386) not found: /home/fgrained-8503.pt
# Tensor (at index: 387) not found: /home/fgrained-8507.pt
# Tensor (at index: 388) not found: /home/fgrained-8511.pt
# Tensor (at index: 389) not found: /home/fgrained-8514.pt
# Tensor (at index: 390) not found: /home/fgrained-8516.pt
# Tensor (at index: 391) not found: /home/fgrained-8520.pt
# Tensor (at index: 392) not found: /home/fgrained-3650.pt
# Tensor (at index: 393) not found: /home/fgrained-7351.pt
# Tensor (at index: 394) not found: /home/fgrained-7397.pt
# Tensor (at index: 395) not found: /home/fgrained-7665.pt
# Tensor (at index: 396) not found: /home/fgrained-7666.pt
# Tensor (at index: 397) not found: /home/fgrained-7669.pt
# Tensor (at index: 398) not found: /home/fgrained-7675.pt
# Tensor (at index: 399) not found: /home/fgrained-8132.pt
# Tensor (at index: 400) not found: /home/fgrained-13275.pt
# Tensor (at index: 401) not found: /home/fgrained-13501.pt
# Tensor (at index: 402) not found: /home/fgrained-13503.pt
# Tensor (at index: 403) not found: /home/fgrained-13885.pt
# Tensor (at index: 404) not found: /home/fgrained-13887.pt
# Tensor (at index: 405) not found: /home/fgrained-13889.pt
# Tensor (at index: 406) not found: /home/fgrained-14064.pt
# Tensor (at index: 407) not found: /home/fgrained-14072.pt
# Tensor (at index: 408) not found: /home/fgrained-14080.pt
# Tensor (at index: 409) not found: /home/fgrained-3663.pt
# Tensor (at index: 410) not found: /home/fgrained-4024.pt
# Tensor (at index: 411) not found: /home/fgrained-4133.pt
# Tensor (at index: 412) not found: /home/fgrained-4296.pt
# Tensor (at index: 413) not found: /home/fgrained-4302.pt
# Tensor (at index: 414) not found: /home/fgrained-4471.pt
# Tensor (at index: 415) not found: /home/fgrained-4606.pt
# Tensor (at index: 416) not found: /home/fgrained-5651.pt
# Tensor (at index: 417) not found: /home/fgrained-7917.pt
# Tensor (at index: 418) not found: /home/fgrained-12823.pt
# Tensor (at index: 419) not found: /home/fgrained-12832.pt
# Tensor (at index: 420) not found: /home/fgrained-13193.pt
# Tensor (at index: 421) not found: /home/fgrained-4527.pt
# Tensor (at index: 422) not found: /home/fgrained-4535.pt
# Tensor (at index: 423) not found: /home/fgrained-7777.pt
# Tensor (at index: 424) not found: /home/fgrained-7788.pt
# Tensor (at index: 425) not found: /home/fgrained-7848.pt
# Tensor (at index: 426) not found: /home/fgrained-13967.pt
# Tensor (at index: 427) not found: /home/fgrained-14014.pt
# Tensor (at index: 428) not found: /home/fgrained-4663.pt
# Tensor (at index: 429) not found: /home/fgrained-4679.pt
# Tensor (at index: 430) not found: /home/fgrained-4695.pt
# Tensor (at index: 431) not found: /home/fgrained-4709.pt
# Tensor (at index: 432) not found: /home/fgrained-4716.pt
# Tensor (at index: 433) not found: /home/fgrained-4725.pt
# Tensor (at index: 434) not found: /home/fgrained-4736.pt
# Tensor (at index: 435) not found: /home/fgrained-13653.pt
# Tensor (at index: 436) not found: /home/fgrained-13678.pt
# Tensor (at index: 437) not found: /home/fgrained-4697.pt
# Tensor (at index: 438) not found: /home/fgrained-4718.pt
# Tensor (at index: 439) not found: /home/fgrained-6247.pt
# Tensor (at index: 440) not found: /home/fgrained-7108.pt
# Tensor (at index: 441) not found: /home/fgrained-7125.pt
# Tensor (at index: 442) not found: /home/fgrained-7290.pt
# Tensor (at index: 443) not found: /home/fgrained-7312.pt
# Tensor (at index: 444) not found: /home/fgrained-13617.pt
# Tensor (at index: 445) not found: /home/fgrained-4808.pt
# Tensor (at index: 446) not found: /home/fgrained-12822.pt
# Tensor (at index: 447) not found: /home/fgrained-12886.pt
# Tensor (at index: 448) not found: /home/fgrained-13490.pt
# Tensor (at index: 449) not found: /home/fgrained-13941.pt
# Tensor (at index: 450) not found: /home/fgrained-13971.pt
# Tensor (at index: 451) not found: /home/fgrained-5551.pt
# Tensor (at index: 452) not found: /home/fgrained-6639.pt
# Tensor (at index: 453) not found: /home/fgrained-11325.pt
# Tensor (at index: 454) not found: /home/fgrained-11326.pt
# Tensor (at index: 455) not found: /home/fgrained-11356.pt
# Tensor (at index: 456) not found: /home/fgrained-11408.pt
# Tensor (at index: 457) not found: /home/fgrained-11944.pt
# Tensor (at index: 458) not found: /home/fgrained-11967.pt
# Tensor (at index: 459) not found: /home/fgrained-11972.pt
# Tensor (at index: 460) not found: /home/fgrained-12030.pt
# Tensor (at index: 461) not found: /home/fgrained-12120.pt
# Tensor (at index: 462) not found: /home/fgrained-12170.pt
# Tensor (at index: 463) not found: /home/fgrained-12193.pt
# Tensor (at index: 464) not found: /home/fgrained-12530.pt
# Tensor (at index: 465) not found: /home/fgrained-12590.pt
# Tensor (at index: 466) not found: /home/fgrained-12954.pt
# Tensor (at index: 467) not found: /home/fgrained-6683.pt
# Tensor (at index: 468) not found: /home/fgrained-6685.pt
# Tensor (at index: 469) not found: /home/fgrained-6699.pt
# Tensor (at index: 470) not found: /home/fgrained-6709.pt
# Tensor (at index: 471) not found: /home/fgrained-6723.pt
# Tensor (at index: 472) not found: /home/fgrained-6724.pt
# Tensor (at index: 473) not found: /home/fgrained-6725.pt
# Tensor (at index: 474) not found: /home/fgrained-6729.pt
# Tensor (at index: 475) not found: /home/fgrained-6762.pt
# Tensor (at index: 476) not found: /home/fgrained-6764.pt
# Tensor (at index: 477) not found: /home/fgrained-6765.pt
# Tensor (at index: 478) not found: /home/fgrained-6767.pt
# Tensor (at index: 479) not found: /home/fgrained-6768.pt
# Tensor (at index: 480) not found: /home/fgrained-6771.pt
# Tensor (at index: 481) not found: /home/fgrained-6772.pt
# Tensor (at index: 482) not found: /home/fgrained-6774.pt
# Tensor (at index: 483) not found: /home/fgrained-6775.pt
# Tensor (at index: 484) not found: /home/fgrained-6780.pt
# Tensor (at index: 485) not found: /home/fgrained-6781.pt
# Tensor (at index: 486) not found: /home/fgrained-6785.pt
# Tensor (at index: 487) not found: /home/fgrained-6789.pt
# Tensor (at index: 488) not found: /home/fgrained-6796.pt
# Tensor (at index: 489) not found: /home/fgrained-6798.pt
# Tensor (at index: 490) not found: /home/fgrained-6810.pt
# Tensor (at index: 491) not found: /home/fgrained-6811.pt
# Tensor (at index: 492) not found: /home/fgrained-6816.pt
# Tensor (at index: 493) not found: /home/fgrained-6822.pt
# Tensor (at index: 494) not found: /home/fgrained-6833.pt
# Tensor (at index: 495) not found: /home/fgrained-6866.pt
# Tensor (at index: 496) not found: /home/fgrained-6911.pt
# Tensor (at index: 497) not found: /home/fgrained-7019.pt
# Tensor (at index: 498) not found: /home/fgrained-7137.pt
# Tensor (at index: 499) not found: /home/fgrained-7291.pt
# Tensor (at index: 500) not found: /home/fgrained-7307.pt
# Tensor (at index: 501) not found: /home/fgrained-7322.pt
# Tensor (at index: 502) not found: /home/fgrained-7344.pt
# Tensor (at index: 503) not found: /home/fgrained-7354.pt
# Tensor (at index: 504) not found: /home/fgrained-7356.pt
# Tensor (at index: 505) not found: /home/fgrained-7381.pt
# Tensor (at index: 506) not found: /home/fgrained-7394.pt
# Tensor (at index: 507) not found: /home/fgrained-7399.pt
# Tensor (at index: 508) not found: /home/fgrained-7402.pt
# Tensor (at index: 509) not found: /home/fgrained-7422.pt
# Tensor (at index: 510) not found: /home/fgrained-13784.pt
# Tensor (at index: 511) not found: /home/fgrained-13797.pt
# Tensor (at index: 512) not found: /home/fgrained-6779.pt
# Tensor (at index: 513) not found: /home/fgrained-6809.pt
# Tensor (at index: 514) not found: /home/fgrained-6997.pt
# Tensor (at index: 515) not found: /home/fgrained-7000.pt
# Tensor (at index: 516) not found: /home/fgrained-7024.pt
# Tensor (at index: 517) not found: /home/fgrained-7077.pt
# Tensor (at index: 518) not found: /home/fgrained-7079.pt
# Tensor (at index: 519) not found: /home/fgrained-6847.pt
# Tensor (at index: 520) not found: /home/fgrained-7646.pt
# Tensor (at index: 521) not found: /home/fgrained-7656.pt
# Tensor (at index: 522) not found: /home/fgrained-13849.pt
# Tensor (at index: 523) not found: /home/fgrained-13862.pt
# Tensor (at index: 524) not found: /home/fgrained-13868.pt
# Tensor (at index: 525) not found: /home/fgrained-13873.pt
# Tensor (at index: 526) not found: /home/fgrained-13877.pt
# Tensor (at index: 527) not found: /home/fgrained-8012.pt
# Tensor (at index: 528) not found: /home/fgrained-8461.pt
# Tensor (at index: 529) not found: /home/fgrained-8611.pt
# Tensor (at index: 530) not found: /home/fgrained-8612.pt
# Tensor (at index: 531) not found: /home/fgrained-8614.pt
# Tensor (at index: 532) not found: /home/fgrained-8617.pt
# Tensor (at index: 533) not found: /home/fgrained-8657.pt
# Tensor (at index: 534) not found: /home/fgrained-8721.pt
# Tensor (at index: 535) not found: /home/fgrained-8781.pt
# Tensor (at index: 536) not found: /home/fgrained-8782.pt
# Tensor (at index: 537) not found: /home/fgrained-8786.pt
# Tensor (at index: 538) not found: /home/fgrained-8788.pt
# Tensor (at index: 539) not found: /home/fgrained-8794.pt
# Tensor (at index: 540) not found: /home/fgrained-8796.pt
# Tensor (at index: 541) not found: /home/fgrained-8800.pt
# Tensor (at index: 542) not found: /home/fgrained-8801.pt
# Tensor (at index: 543) not found: /home/fgrained-8818.pt
# Tensor (at index: 544) not found: /home/fgrained-8824.pt
# Tensor (at index: 545) not found: /home/fgrained-8831.pt
# Tensor (at index: 546) not found: /home/fgrained-9440.pt
# Tensor (at index: 547) not found: /home/fgrained-9441.pt
# Tensor (at index: 548) not found: /home/fgrained-9446.pt
# Tensor (at index: 549) not found: /home/fgrained-9469.pt
# Tensor (at index: 550) not found: /home/fgrained-8014.pt
# Tensor (at index: 551) not found: /home/fgrained-8022.pt
# Tensor (at index: 552) not found: /home/fgrained-8038.pt
# Tensor (at index: 553) not found: /home/fgrained-8039.pt
# Tensor (at index: 554) not found: /home/fgrained-8279.pt
# Tensor (at index: 555) not found: /home/fgrained-8446.pt
# Tensor (at index: 556) not found: /home/fgrained-8449.pt
# Tensor (at index: 557) not found: /home/fgrained-8666.pt
# Tensor (at index: 558) not found: /home/fgrained-8825.pt
# Tensor (at index: 559) not found: /home/fgrained-9448.pt
# Tensor (at index: 560) not found: /home/fgrained-9450.pt
# Tensor (at index: 561) not found: /home/fgrained-9453.pt
# Tensor (at index: 562) not found: /home/fgrained-8398.pt
# Tensor (at index: 563) not found: /home/fgrained-8468.pt
# Tensor (at index: 564) not found: /home/fgrained-8471.pt
# Tensor (at index: 565) not found: /home/fgrained-8473.pt
# Tensor (at index: 566) not found: /home/fgrained-8517.pt
# Tensor (at index: 567) not found: /home/fgrained-9344.pt
# Tensor (at index: 568) not found: /home/fgrained-8431.pt
# Tensor (at index: 569) not found: /home/fgrained-8432.pt
# Tensor (at index: 570) not found: /home/fgrained-8433.pt
# Tensor (at index: 571) not found: /home/fgrained-8434.pt
# Tensor (at index: 572) not found: /home/fgrained-8436.pt
# Tensor (at index: 573) not found: /home/fgrained-8438.pt
# Tensor (at index: 574) not found: /home/fgrained-8869.pt
# Tensor (at index: 575) not found: /home/fgrained-8889.pt
# Tensor (at index: 576) not found: /home/fgrained-8898.pt
# Tensor (at index: 577) not found: /home/fgrained-11145.pt
# Tensor (at index: 578) not found: /home/fgrained-11166.pt
# Tensor (at index: 579) not found: /home/fgrained-11171.pt
# Tensor (at index: 580) not found: /home/fgrained-11181.pt
# Tensor (at index: 581) not found: /home/fgrained-11200.pt
# Tensor (at index: 582) not found: /home/fgrained-11711.pt
# Tensor (at index: 583) not found: /home/fgrained-11737.pt
# Tensor (at index: 584) not found: /home/fgrained-12552.pt
# Tensor (at index: 585) not found: /home/fgrained-9414.pt
# Tensor (at index: 586) not found: /home/fgrained-9415.pt
# Tensor (at index: 587) not found: /home/fgrained-9416.pt
# Tensor (at index: 588) not found: /home/fgrained-9417.pt
# Tensor (at index: 589) not found: /home/fgrained-9882.pt
# Tensor (at index: 590) not found: /home/fgrained-10309.pt
# Tensor (at index: 591) not found: /home/fgrained-11545.pt
# Tensor (at index: 592) not found: /home/fgrained-12145.pt
# Tensor (at index: 593) not found: /home/fgrained-12194.pt
# Tensor (at index: 594) not found: /home/fgrained-9533.pt
# Tensor (at index: 595) not found: /home/fgrained-10031.pt
# Tensor (at index: 596) not found: /home/fgrained-10095.pt
# Tensor (at index: 597) not found: /home/fgrained-10100.pt
# Tensor (at index: 598) not found: /home/fgrained-10433.pt
# Tensor (at index: 599) not found: /home/fgrained-10438.pt
# Tensor (at index: 600) not found: /home/fgrained-11154.pt
# Tensor (at index: 601) not found: /home/fgrained-9877.pt
# Tensor (at index: 602) not found: /home/fgrained-11617.pt
# Tensor (at index: 603) not found: /home/fgrained-11618.pt
# Tensor (at index: 604) not found: /home/fgrained-11623.pt
# Tensor (at index: 605) not found: /home/fgrained-12253.pt
# Tensor (at index: 606) not found: /home/fgrained-12653.pt
# Tensor (at index: 607) not found: /home/fgrained-9890.pt
# Tensor (at index: 608) not found: /home/fgrained-11585.pt
# Tensor (at index: 609) not found: /home/fgrained-11625.pt
# Tensor (at index: 610) not found: /home/fgrained-12169.pt
# Tensor (at index: 611) not found: /home/fgrained-12567.pt
# Tensor (at index: 612) not found: /home/fgrained-12568.pt
# Tensor (at index: 613) not found: /home/fgrained-12600.pt
# Tensor (at index: 614) not found: /home/fgrained-12947.pt
# Tensor (at index: 615) not found: /home/fgrained-12957.pt
# Tensor (at index: 616) not found: /home/fgrained-12958.pt
# Tensor (at index: 617) not found: /home/fgrained-12992.pt
# Tensor (at index: 618) not found: /home/fgrained-12995.pt
# Tensor (at index: 619) not found: /home/fgrained-9896.pt
# Tensor (at index: 620) not found: /home/fgrained-9898.pt
# Tensor (at index: 621) not found: /home/fgrained-9902.pt
# Tensor (at index: 622) not found: /home/fgrained-9909.pt
# Tensor (at index: 623) not found: /home/fgrained-9911.pt
# Tensor (at index: 624) not found: /home/fgrained-9917.pt
# Tensor (at index: 625) not found: /home/fgrained-9924.pt
# Tensor (at index: 626) not found: /home/fgrained-10402.pt
# Tensor (at index: 627) not found: /home/fgrained-10405.pt
# Tensor (at index: 628) not found: /home/fgrained-10406.pt
# Tensor (at index: 629) not found: /home/fgrained-10408.pt
# Tensor (at index: 630) not found: /home/fgrained-10411.pt
# Tensor (at index: 631) not found: /home/fgrained-12277.pt
# Tensor (at index: 632) not found: /home/fgrained-12703.pt
# Tensor (at index: 633) not found: /home/fgrained-12721.pt
# Tensor (at index: 634) not found: /home/fgrained-10104.pt
# Tensor (at index: 635) not found: /home/fgrained-11237.pt
# Tensor (at index: 636) not found: /home/fgrained-11329.pt
# Tensor (at index: 637) not found: /home/fgrained-11377.pt
# Tensor (at index: 638) not found: /home/fgrained-11423.pt
# Tensor (at index: 639) not found: /home/fgrained-11462.pt
# Tensor (at index: 640) not found: /home/fgrained-11464.pt
# Tensor (at index: 641) not found: /home/fgrained-11506.pt
# Tensor (at index: 642) not found: /home/fgrained-11507.pt
# Tensor (at index: 643) not found: /home/fgrained-11547.pt
# Tensor (at index: 644) not found: /home/fgrained-11553.pt
# Tensor (at index: 645) not found: /home/fgrained-11554.pt
# Tensor (at index: 646) not found: /home/fgrained-11997.pt
# Tensor (at index: 647) not found: /home/fgrained-12009.pt
# Tensor (at index: 648) not found: /home/fgrained-12037.pt
# Tensor (at index: 649) not found: /home/fgrained-12050.pt
# Tensor (at index: 650) not found: /home/fgrained-12054.pt
# Tensor (at index: 651) not found: /home/fgrained-12098.pt
# Tensor (at index: 652) not found: /home/fgrained-12105.pt
# Tensor (at index: 653) not found: /home/fgrained-12111.pt
# Tensor (at index: 654) not found: /home/fgrained-12113.pt
# Tensor (at index: 655) not found: /home/fgrained-12174.pt
# Tensor (at index: 656) not found: /home/fgrained-12184.pt
# Tensor (at index: 657) not found: /home/fgrained-12218.pt
# Tensor (at index: 658) not found: /home/fgrained-12577.pt
# Tensor (at index: 659) not found: /home/fgrained-12608.pt
# Tensor (at index: 660) not found: /home/fgrained-11150.pt
# Tensor (at index: 661) not found: /home/fgrained-11201.pt
# Tensor (at index: 662) not found: /home/fgrained-11346.pt
# Tensor (at index: 663) not found: /home/fgrained-11508.pt
# Tensor (at index: 664) not found: /home/fgrained-11521.pt
# Tensor (at index: 665) not found: /home/fgrained-11523.pt
# Tensor (at index: 666) not found: /home/fgrained-11556.pt
# Tensor (at index: 667) not found: /home/fgrained-11562.pt
# Tensor (at index: 668) not found: /home/fgrained-11592.pt
# Tensor (at index: 669) not found: /home/fgrained-12536.pt
# Tensor (at index: 670) not found: /home/fgrained-12548.pt
# Tensor (at index: 671) not found: /home/fgrained-12942.pt
# Tensor (at index: 672) not found: /home/fgrained-12960.pt
# Tensor (at index: 673) not found: /home/fgrained-12966.pt
# Tensor (at index: 674) not found: /home/fgrained-11350.pt
# Tensor (at index: 675) not found: /home/fgrained-11800.pt
# Tensor (at index: 676) not found: /home/fgrained-11807.pt
# Tensor (at index: 677) not found: /home/fgrained-11853.pt
# Tensor (at index: 678) not found: /home/fgrained-11940.pt
# Tensor (at index: 679) not found: /home/fgrained-11982.pt
# Tensor (at index: 680) not found: /home/fgrained-12506.pt
# Tensor (at index: 681) not found: /home/fgrained-12509.pt
# Tensor (at index: 682) not found: /home/fgrained-11779.pt
# Tensor (at index: 683) not found: /home/fgrained-12461.pt
# Tensor (at index: 684) not found: /home/fgrained-12465.pt
# Tensor (at index: 685) not found: /home/fgrained-12468.pt
# Tensor (at index: 686) not found: /home/fgrained-12469.pt
# Tensor (at index: 687) not found: /home/fgrained-12471.pt
# Tensor (at index: 688) not found: /home/fgrained-12475.pt
# Tensor (at index: 689) not found: /home/fgrained-12476.pt
# Tensor (at index: 690) not found: /home/fgrained-12486.pt
# Tensor (at index: 691) not found: /home/fgrained-12487.pt
# Tensor (at index: 692) not found: /home/fgrained-11784.pt
# Tensor (at index: 693) not found: /home/fgrained-11834.pt
# Tensor (at index: 694) not found: /home/fgrained-11966.pt
# Tensor (at index: 695) not found: /home/fgrained-11970.pt
# Tensor (at index: 696) not found: /home/fgrained-11991.pt
# Tensor (at index: 697) not found: /home/fgrained-12511.pt
# >>> Starting creating tensors with 18 workers
# Tensor (at index: 17) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-6094.pt
# Tensor (at index: 2) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-3340.pt
# Tensor (at index: 13) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5375.pt
# Tensor (at index: 14) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5858.pt
# Tensor (at index: 5) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12180.pt
# Tensor (at index: 11) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5270.pt
# Tensor (at index: 4) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12171.pt
# Tensor (at index: 6) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12204.pt
# Tensor (at index: 9) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12773.pt
# Tensor (at index: 7) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12555.pt
# Tensor (at index: 12) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5359.pt
# Tensor (at index: 15) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5882.pt
# Tensor (at index: 3) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-8222.pt
# Tensor (at index: 16) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-6079.pt
# Tensor (at index: 8) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12596.pt
# Tensor (at index: 1) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-29.pt
# Tensor (at index: 10) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-49.pt
# Tensor (at index: 0) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-26.pt
# Tensor (at index: 19) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-6468.pt
# Tensor (at index: 18) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-6106.pt
# Tensor (at index: 21) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-13622.pt
# Tensor (at index: 22) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-13803.pt
# Tensor (at index: 23) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-14081.pt
# Tensor (at index: 20) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-6633.pt
# Tensor (at index: 31) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5585.pt
# Tensor (at index: 41) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-994.pt
# Tensor (at index: 29) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5796.pt
# Tensor (at index: 27) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-13022.pt
# Tensor (at index: 24) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5975.pt
# Tensor (at index: 25) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-456.pt
# Tensor (at index: 33) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-2626.pt
# Tensor (at index: 37) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-13620.pt
# Tensor (at index: 28) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5333.pt
# Tensor (at index: 30) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-6280.pt
# Tensor (at index: 35) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-13635.pt
# Tensor (at index: 32) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-723.pt
# Tensor (at index: 26) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5200.pt
# Tensor (at index: 34) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5739.pt
# Tensor (at index: 38) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5413.pt
# Tensor (at index: 40) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-6214.pt
# Tensor (at index: 50) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-13767.pt
# Tensor (at index: 39) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5169.pt
# Tensor (at index: 42) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5237.pt
# Tensor (at index: 36) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-13652.pt
# Tensor (at index: 44) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-13682.pt
# Tensor (at index: 45) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-1026.pt
# Tensor (at index: 46) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5346.pt
# Tensor (at index: 43) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-1143.pt
# Tensor (at index: 48) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-2679.pt
# Tensor (at index: 49) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5362.pt
# Tensor (at index: 47) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5487.pt
# Tensor (at index: 64) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-5990.pt
# ...
# Tensor (at index: 2028) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11231.pt
# Tensor (at index: 2026) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-9964.pt
# Tensor (at index: 2027) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-10211.pt
# Tensor (at index: 2037) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11855.pt
# Tensor (at index: 2030) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11915.pt
# Tensor (at index: 2033) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11157.pt
# Tensor (at index: 2039) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11881.pt
# Tensor (at index: 2036) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11835.pt
# Tensor (at index: 2025) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-9962.pt
# Tensor (at index: 2034) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11598.pt
# Tensor (at index: 2038) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11857.pt
# Tensor (at index: 2046) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12441.pt
# Tensor (at index: 2042) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11926.pt
# Tensor (at index: 2048) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12772.pt
# Tensor (at index: 2044) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12227.pt
# Tensor (at index: 2050) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11228.pt
# Tensor (at index: 2040) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11918.pt
# Tensor (at index: 2049) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11199.pt
# Tensor (at index: 2054) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11345.pt
# Tensor (at index: 2045) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12228.pt
# Tensor (at index: 2056) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11354.pt
# Tensor (at index: 2041) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11924.pt
# Tensor (at index: 2057) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11363.pt
# Tensor (at index: 2052) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11262.pt
# Tensor (at index: 2047) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12477.pt
# Tensor (at index: 2051) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11253.pt
# Tensor (at index: 2043) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11953.pt
# Tensor (at index: 2053) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11288.pt
# Tensor (at index: 2055) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11349.pt
# Tensor (at index: 2065) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11535.pt
# Tensor (at index: 2064) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11412.pt
# Tensor (at index: 2060) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11383.pt
# Tensor (at index: 2066) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11541.pt
# Tensor (at index: 2062) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11406.pt
# Tensor (at index: 2063) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11410.pt
# Tensor (at index: 2070) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11286.pt
# Tensor (at index: 2061) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11401.pt
# Tensor (at index: 2058) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11365.pt
# Tensor (at index: 2069) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12941.pt
# Tensor (at index: 2059) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11378.pt
# Tensor (at index: 2067) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11569.pt
# Tensor (at index: 2068) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12788.pt
# Tensor (at index: 2079) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12504.pt
# Tensor (at index: 2083) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12670.pt
# Tensor (at index: 2077) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12426.pt
# Tensor (at index: 2076) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12423.pt
# Tensor (at index: 2085) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12673.ptTensor (at index: 2073) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12328.pt
#
# Tensor (at index: 2078) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12463.pt
# Tensor (at index: 2072) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12249.pt
# Tensor (at index: 2080) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12528.pt
# Tensor (at index: 2075) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12355.pt
# Tensor (at index: 2071) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11913.pt
# Tensor (at index: 2074) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12341.pt
# Tensor (at index: 2081) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12562.pt
# Tensor (at index: 2082) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12660.pt
# Tensor (at index: 2086) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12687.pt
# Tensor (at index: 2084) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12672.pt
# Tensor (at index: 2090) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11375.pt
# Tensor (at index: 2088) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11364.pt
# Tensor (at index: 2087) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12719.pt
# Tensor (at index: 2089) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11369.pt
# Tensor (at index: 2097) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12010.pt
# Tensor (at index: 2105) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12140.pt
# Tensor (at index: 2101) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12124.pt
# Tensor (at index: 2108) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12148.pt
# Tensor (at index: 2104) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12128.pt
# Tensor (at index: 2107) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12147.pt
# Tensor (at index: 2099) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12107.pt
# Tensor (at index: 2100) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12109.pt
# Tensor (at index: 2094) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11962.pt
# Tensor (at index: 2096) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12005.pt
# Tensor (at index: 2095) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11998.pt
# Tensor (at index: 2103) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12127.pt
# Tensor (at index: 2092) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11948.pt
# Tensor (at index: 2102) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12125.pt
# Tensor (at index: 2093) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11958.pt
# Tensor (at index: 2098) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12044.pt
# Tensor (at index: 2106) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12146.pt
# Tensor (at index: 2118) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12564.pt
# Tensor (at index: 2110) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12160.pt
# Tensor (at index: 2116) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12531.pt
# Tensor (at index: 2109) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12159.pt
# Tensor (at index: 2112) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12164.pt
# Tensor (at index: 2114) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12181.pt
# Tensor (at index: 2120) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12584.pt
# Tensor (at index: 2117) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12559.pt
# Tensor (at index: 2113) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12173.pt
# Tensor (at index: 2115) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12220.pt
# Tensor (at index: 2123) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12587.pt
# Tensor (at index: 2121) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12585.pt
# Tensor (at index: 2119) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12582.pt
# Tensor (at index: 2111) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12161.pt
# Tensor (at index: 2122) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12586.pt
# Tensor (at index: 2124) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12591.pt
# Tensor (at index: 2091) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11431.pt
# Tensor (at index: 2127) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12594.pt
# Tensor (at index: 2128) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12595.pt
# Tensor (at index: 2136) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12237.pt
# Tensor (at index: 2134) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11658.pt
# Tensor (at index: 2133) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11642.pt
# Tensor (at index: 2125) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12592.pt
# Tensor (at index: 2131) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12629.pt
# Tensor (at index: 2130) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12617.pt
# Tensor (at index: 2137) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12649.pt
# Tensor (at index: 2126) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12593.pt
# Tensor (at index: 2135) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12151.pt
# Tensor (at index: 2129) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-12599.pt
# Tensor (at index: 2132) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/adapted/resized/low/fgrained-11583.pt
# >>> Save updated Dataframe to: /home/jleick/masterArbeitProjekt/final_release/data/datasets/created/embedding_resized/low_id_test.csv
# >>> FINISH Process: low_id_test.csv
