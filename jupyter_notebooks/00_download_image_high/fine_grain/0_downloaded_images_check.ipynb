# %% [markdown]
# # Notebook overview
# Summarizes successful and failed image downloads and failure reasons for the fine-grain GBIF dataset.
#
# - Loads download-check CSVs for train/val/test splits
# - Checks 'image_downloaded' counts and aggregates 'image_download_fail_reason'
# - Prints per-split counts of download issues

# %% [markdown]
# # Description
# Summary of successfully and unsuccessfully downloaded images and the reasons for failure.

# %% [markdown]
# # Preperation

# %% [markdown]
# ### Import

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Path - df_base_dir

# %%
# The base path on which the other paths in this code are built.

DF_BASE_DIR = r'/home/jleick/masterArbeitProjekt/final_release/data/datasets/origin/download'
df_base_dir = Path(DF_BASE_DIR)

# %% [markdown]
# ### Load dfs - high_id_train, high_id_val, high_id_test

# %%
high_id_train = pd.read_csv( df_base_dir/'04_ami-gbif_fine-grained_all_train_download.csv')
high_id_val = pd.read_csv( df_base_dir/'04_ami-gbif_fine-grained_all_val_download.csv')
high_id_test = pd.read_csv( df_base_dir/'04_ami-gbif_fine-grained_all_test_download.csv')

# %% [markdown]
# # check

# %% [markdown]
# ### check - 'image_downloaded'

# %%
print(f'train id: {high_id_train['image_downloaded'].value_counts()} \n' )
print(f'val id: {high_id_val['image_downloaded'].value_counts()} \n' )
print(f'test id: {high_id_test['image_downloaded'].value_counts()} \n\n' )
# Out:
# train id: image_downloaded
# True     1235648
# False     663534
# Name: count, dtype: int64
#
# val id: image_downloaded
# True     217625
# False      3931
# Name: count, dtype: int64
#
# test id: image_downloaded
# True     439613
# False      4041
# Name: count, dtype: int64

# %% [markdown]
# ### check - 'image_download_fail_reason'

# %%
print(f'train id: {high_id_train['image_download_fail_reason'].str.extract(r'^([^:]+:[^:]+):|^(.*)$', expand=True).bfill(axis=1).iloc[:, 0].value_counts()} \n' )
print(f'val id: {high_id_val['image_download_fail_reason'].str.extract(r'^([^:]+:[^:]+):|^(.*)$', expand=True).bfill(axis=1).iloc[:, 0].value_counts()} \n' )
print(f'test id: {high_id_test['image_download_fail_reason'].str.extract(r'^([^:]+:[^:]+):|^(.*)$', expand=True).bfill(axis=1).iloc[:, 0].value_counts()} \n\n' )
# Out:
# train id: 0
# no error                                                                                                                                                                                                                   1235648
# HTTPSConnectionPool(host='inaturalist-open-data.s3.amazonaws.com', port=443): Max retries exceeded with url                                                                                                                 308987
# HTTPSConnectionPool(host='observation.org', port=443): Max retries exceeded with url                                                                                                                                        145429
# HTTPSConnectionPool(host='www.artportalen.se', port=443): Max retries exceeded with url                                                                                                                                      37044
# 404 Client Error: Not Found for url                                                                                                                                                                                          22575
#                                                                                                                                                                                                                             ...
# [Errno 24] Too many open files: '/home/jleick/masterArbeitProjekt/data/ami_download_temp/ami_gbif/fetched_images_fine-grained/04_ami-gbif_fine-grained_all_train/8a863029-f435-446a-821e-275f4f641165/3722562440.jpg'            1
# [Errno 24] Too many open files: '/home/jleick/masterArbeitProjekt/data/ami_download_temp/ami_gbif/fetched_images_fine-grained/04_ami-gbif_fine-grained_all_train/50c9509d-22c7-4a22-a47d-8c48425ef4a7/4405534363_1.jpg'          1
# [Errno 24] Too many open files: '/home/jleick/masterArbeitProjekt/data/ami_download_temp/ami_gbif/fetched_images_fine-grained/04_ami-gbif_fine-grained_all_train/8a863029-f435-446a-821e-275f4f641165/1969860344.jpg'            1
# [Errno 24] Too many open files: '/home/jleick/masterArbeitProjekt/data/ami_download_temp/ami_gbif/fetched_images_fine-grained/04_ami-gbif_fine-grained_all_train/8a863029-f435-446a-821e-275f4f641165/4056227148.jpg'            1
# [Errno 24] Too many open files: '/home/jleick/masterArbeitProjekt/data/ami_download_temp/ami_gbif/fetched_images_fine-grained/04_ami-gbif_fine-grained_all_train/8a863029-f435-446a-821e-275f4f641165/3720875464.jpg'            1
# Name: count, Length: 63548, dtype: int64
#
# val id: 0
# no error                                                                                                            217625
# 404 Client Error: Not Found for url                                                                                   3844
# HTTPSConnectionPool(host='specify-attachments.science.ku.dk', port=443): Max retries exceeded with url                  40
# 503 Server Error: Backend fetch failed for url                                                                          24
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))                             9
# HTTPConnectionPool(host='www.ngbif.org.ng', port=80): Max retries exceeded with url                                      4
# HTTPSConnectionPool(host='www.artportalen.se', port=443): Read timed out. (read timeout=300)                             4
# 504 Server Error: Gateway Time-out for url                                                                               2
# HTTPSConnectionPool(host='inaturalist-open-data.s3.amazonaws.com', port=443): Read timed out. (read timeout=300)         1
# 500 Server Error: Internal Server Error for url                                                                          1
# 415 Client Error: Unsupported Media Type for url                                                                         1
# HTTPConnectionPool(host='mediaphoto.mnhn.fr', port=80): Max retries exceeded with url                                    1
# Name: count, dtype: int64
#
# test id: 0
# no error                                                                                        439611
# 404 Client Error: Not Found for url                                                               4033
# 403 Client Error: Forbidden for url                                                                  4
# False                                                                                                2
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))         2
# HTTPConnectionPool(host='www.ngbif.org.ng', port=80): Max retries exceeded with url                  2
# Name: count, dtype: int64
