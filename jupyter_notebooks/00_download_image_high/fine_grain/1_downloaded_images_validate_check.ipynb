# %% [markdown]
# # Notebook overview
# Summarizes validated image downloads for the fine-grain GBIF dataset, reporting successes and failure reasons.
#
# - Loads download-check CSVs for train/val/test splits
# - Verifies 'image_downloaded' counts and aggregates 'image_download_fail_reason'
# - Prints per-split counts

# %% [markdown]
# # Preperation

# %% [markdown]
# ### Import

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Path - df_base_dir

# %%
DF_BASE_DIR = r'/home/jleick/masterArbeitProjekt/final_release/data/datasets/origin/download_check'
df_base_dir = Path(DF_BASE_DIR)

# %% [markdown]
# ### Load dfs - high_id_train, high_id_val, high_id_test

# %%
high_id_train = pd.read_csv( df_base_dir/'04_ami-gbif_fine-grained_all_train_download_check.csv')
high_id_val = pd.read_csv( df_base_dir/'04_ami-gbif_fine-grained_all_val_download_check.csv')
high_id_test = pd.read_csv( df_base_dir/'04_ami-gbif_fine-grained_all_test_download_check.csv')

# %% [markdown]
# # check

# %% [markdown]
# ### check - 'image_downloaded'

# %%
print(f'train id: {high_id_train['image_downloaded'].value_counts()} \n' )
print(f'val id: {high_id_val['image_downloaded'].value_counts()} \n' )
print(f'test id: {high_id_test['image_downloaded'].value_counts()} \n\n' )
# Out:
# train id: image_downloaded
# True     1866868
# False      32314
# Name: count, dtype: int64
#
# val id: image_downloaded
# True     217774
# False      3782
# Name: count, dtype: int64
#
# test id: image_downloaded
# True     436270
# False      7384
# Name: count, dtype: int64

# %% [markdown]
# ### check - 'image_download_fail_reason'

# %%
print(f'train id: {high_id_train['image_download_fail_reason'].str.extract(r'^([^:]+:[^:]+):|^(.*)$', expand=True).bfill(axis=1).iloc[:, 0].value_counts()} \n' )
print(f'val id: {high_id_val['image_download_fail_reason'].str.extract(r'^([^:]+:[^:]+):|^(.*)$', expand=True).bfill(axis=1).iloc[:, 0].value_counts()} \n' )
print(f'test id: {high_id_test['image_download_fail_reason'].str.extract(r'^([^:]+:[^:]+):|^(.*)$', expand=True).bfill(axis=1).iloc[:, 0].value_counts()} \n\n' )
# Out:
# train id: 0
# no error                                                                                                            1866868
# 404 Client Error: Not Found for url                                                                                   31277
# HTTPSConnectionPool(host='scan-bugs.org', port=443): Max retries exceeded with url                                      798
# HTTPSConnectionPool(host='id.digitarium.fi', port=443): Max retries exceeded with url                                    98
# 403 Client Error: Forbidden for url                                                                                      56
# invalid image file                                                                                                       34
# HTTPConnectionPool(host='www.ngbif.org.ng', port=80): Max retries exceeded with url                                      21
# HTTPConnectionPool(host='mediaphoto.mnhn.fr', port=80): Max retries exceeded with url                                     9
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))                              9
# HTTPSConnectionPool(host='image.laji.fi', port=443): Max retries exceeded with url                                        3
# HTTPSConnectionPool(host='inaturalist-open-data.s3.amazonaws.com', port=443): Max retries exceeded with url               3
# HTTPSConnectionPool(host='files.plutof.ut.ee', port=443): Read timed out. (read timeout=300)                              2
# HTTPSConnectionPool(host='boldsystems.org', port=443): Read timed out. (read timeout=300)                                 1
# HTTPSConnectionPool(host='images.collections.yale.edu', port=443): Read timed out. (read timeout=300)                     1
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))                                            1
# HTTPSConnectionPool(host='inaturalist-open-data.s3.amazonaws.com', port=443): Read timed out. (read timeout=300)          1
# Name: count, dtype: int64
#
# val id: 0
# no error                                                                                                       217774
# 404 Client Error: Not Found for url                                                                              3770
# HTTPConnectionPool(host='www.ngbif.org.ng', port=80): Max retries exceeded with url                                 4
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))                                      2
# invalid image file                                                                                                  2
# HTTPSConnectionPool(host='inaturalist-open-data.s3.amazonaws.com', port=443): Max retries exceeded with url         2
# HTTPSConnectionPool(host='www.artportalen.se', port=443): Max retries exceeded with url                             1
# HTTPSConnectionPool(host='files.plutof.ut.ee', port=443): Read timed out. (read timeout=300)                        1
# Name: count, dtype: int64
#
# test id: 0
# no error                                                                               436270
# 404 Client Error: Not Found for url                                                      7368
# invalid image file                                                                         10
# 403 Client Error: Forbidden for url                                                         4
# HTTPConnectionPool(host='www.ngbif.org.ng', port=80): Max retries exceeded with url         2
# Name: count, dtype: int64
