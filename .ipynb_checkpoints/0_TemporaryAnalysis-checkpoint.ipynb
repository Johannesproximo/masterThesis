# %%
import timm
import pandas as pd
import os
import torch

# %%
PATH_DATA_BINARY_TEST = r'/home/jleick/masterArbeitProjekt/data/ami_dataset/ami_gbif/binary_classification/metadata/ami-gbif_binary_test_Download.csv'

# %%
df_binary_test = pd.read_csv(PATH_DATA_BINARY_TEST)

df_binary_test.loc[3411, ['identifier']]
# Out:
# identifier    https://medialib.naturalis.nl/file/id/RMNH.INS...
# Name: 3411, dtype: object

# %%
dir(df_binary_test)

tensor_list = sorted(os.listdir('/home/jleick/masterArbeitProjekt/data/ami_dataset/ami_gbif/binary_classification/nonMothsTestVectorsTemp'))
tensor_list
tensor_list[1]
# Out:
# '1.3717422034.pt'

# %%
tensor_1 = torch.load('/home/jleick/masterArbeitProjekt/data/ami_dataset/ami_gbif/binary_classification/nonMothsTestVectorsTemp/0.2813899724.pt', weights_only=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tensor_1 = torch.load('/home/jleick/masterArbeitProjekt/data/ami_dataset/ami_gbif/binary_classification/nonMothsTestVectorsTemp/0.2813899724.pt', weights_only=True)
#
# NameError: name 'torch' is not defined
