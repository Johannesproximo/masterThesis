# %% [markdown]
# # Notebook overview
# This notebook generates image embeddings using DINOv2 (timm), saves them as .pt files, and updates the corresponding CSV files.
#
# - Loads a pretrained DINOv2 model and preprocessing pipeline
# - Loads CSV files (train/val/test) and adds tracking columns
# - Copies existing embeddings from a cache
# - Creates missing embeddings in parallel (ThreadPoolExecutor) and saves them
# - Saves the updated CSVs; paths are configurable at the top;
#
# The notebook was exported as a Python script and run in a console using Tmux to execute it. The notebook was used for images of all datasets just adapte the paths.

# %% [markdown]
# ## Modul Importe

# %%
import pandas as pd
import timm
import torch

import os
import shutil
from typing import Optional
from PIL import Image

from concurrent.futures import ThreadPoolExecutor, as_completed
import subprocess

# %%
# Number of Threads
MAX_WORKERS = 18

# Folder with CSV files (train, test, val)
CSV_SOURCE_FOLDER_PATH = r'/data/datasets/created'
if not os.path.exists(CSV_SOURCE_FOLDER_PATH):
    raise FileNotFoundError(f"Folder does not exist: {CSV_SOURCE_FOLDER_PATH}")

# Folder to save adapted CSV files (train, test, val)
CSV_DESTINATION_FOLDER_PATH = r'/data/datasets/created/embedding_copied'
if not os.path.exists(CSV_DESTINATION_FOLDER_PATH):
    raise FileNotFoundError(f"Folder does not exist: {CSV_DESTINATION_FOLDER_PATH}")

# Folder with downloaded images
IMAGE_FOLDER_PATH = r'/data/images/original/high'
if not os.path.exists(IMAGE_FOLDER_PATH):
    raise FileNotFoundError(f"Folder does not exist: {IMAGE_FOLDER_PATH}")

# Folder to save the embeddings of images
DESTINATION_PATH = r'/data/embeddings/original/high'

# Cache folder for available embeddings
CACHE = r'/data/embeddings/cached'

# %%
### Select csv files in given folder Path

def select_files(csv_source_folder_path: str):
    folder_contains = os.listdir(csv_source_folder_path)
    folder_filtered = [] 
    # Filter all relevant files
    for filename in folder_contains:
        ### adapt conditions for specific csv files in folder
        if ('high' in filename): # and 'val' in filename):
            folder_filtered.append(filename)

    return folder_filtered

#call funktion
selected_csv_files = select_files(CSV_SOURCE_FOLDER_PATH)

# Print all selected files
for folder_name in selected_csv_files:
    print(folder_name)

# DUBLICATED CODE (CODE EXIST IN OTHER FILE TOO)
# Out:
# high_id_val.csv
# high_id_test.csv
# high_ood_test.csv
# high_id_train.csv

# %%
### Load CSV data into Pandas DataFrame


def load_data(data_path: str, nrows: Optional[int] = None):
    # Load data into Pandas DataFrame
    df = pd.read_csv(data_path, sep=",", header="infer", nrows=nrows)
    # print(f'{df.shape} - Shape of: {data_path.split("/")[-1]}')

    # Print Columns with only NaN in Column
    # empty_columns = df.columns[df.isna().all()]
    # print(f'column: {list(empty_columns)} contains only NaN')

    # Check if df contains duplicated URLs
    if not df["identifier"].is_unique:
        duplicates = df["identifier"].duplicated(keep=False).sum()
        print(f"Duplicate: {duplicates} are included in identifier")
        # raise Exception('Duplicates are included in identifier') # assert url_list.is_unique

    return df


### Test function
# test_path = os.path.join(CSV_SOURCE_FOLDER_PATH, selected_csv_files[1])
# data_temp = load_data(test_path, 5)
# data_temp

### DUBLICATED CODE (CODE EXIST IN OTHER FILE TOO)

# %%
### add column to track existing tensors 'tensor_created'


def add_embedding_column_to_df(df: pd.DataFrame):

    column_name_embedding = "embedding_created"
    if column_name_embedding not in df.columns:
        df[column_name_embedding] = False
        print(f'>>> {df.shape} - Added column: {column_name_embedding}')

    column_name_embedding_fail = 'embedding_created_fail'
    if column_name_embedding_fail not in df.columns:
        df[column_name_embedding_fail] = 'NaN'
        print(f'>>> {df.shape} - Added column: {column_name_embedding_fail}')
    
    return column_name_embedding, column_name_embedding_fail


### Test function
# column_name_embedding = add_embedding_column_to_df(data_temp)
# print( f'return: {column_name_embedding}' )
# data_temp

# %%
### Load the model
dinov2_vits14 = timm.create_model("vit_small_patch14_dinov2.lvd142m", pretrained=True)
dinov2_vits14.eval()

### Set device (NICHT GETESTET)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on device {device}.")

dinov2_vits14.to(device)

### Load preprocessing pipeline
data_cfg = timm.data.resolve_data_config(dinov2_vits14.pretrained_cfg)
transform = timm.data.create_transform(**data_cfg)

type(dinov2_vits14)

### transform settings
# dinov2_vits14.pretrained_cfg
data_cfg # is it usefull to do normalisation and if yes on default values
# Out:
# Training on device cuda.
# {'input_size': (3, 518, 518),
#  'interpolation': 'bicubic',
#  'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),
#  'crop_pct': 1.0,
#  'crop_mode': 'center'}

# %%
transform
# Out:
# Compose(
#     Resize(size=518, interpolation=bicubic, max_size=None, antialias=True)
#     CenterCrop(size=(518, 518))
#     MaybeToTensor()
#     Normalize(mean=tensor([0.4850, 0.4560, 0.4060]), std=tensor([0.2290, 0.2240, 0.2250]))
# )

# %%
### copy availables images from cache to destination


def change_file_extension_to_pt(file_path: str):
    base, ext = os.path.splitext(file_path)
    return base + ".pt"


def copy_availabe_embeddings(
    df: pd.DataFrame, source_dir: str, destination_dir: str, column_name_embedding: str, column_name_embedding_fail: str
):
    for index, image_pfad in df["image_path"].items():
        tensor_pfad = change_file_extension_to_pt(image_pfad)
        source_path = os.path.join(source_dir, tensor_pfad)

        # check if image embedding in cache exists
        if os.path.exists(source_path):
            try:
                destination_path = os.path.join(destination_dir, tensor_pfad)

                # check if image embedding in destination already exists
                if not os.path.exists(destination_path):
                    os.makedirs(os.path.dirname(destination_path), exist_ok=True)
                    shutil.copyfile(source_path, destination_path)

                    df.at[index, column_name_embedding] = True
                    df.at[index, column_name_embedding_fail] = "no error"
                    print(f"Tensor (at index: {index}) found and copied: {destination_path}")
                else:
                    df.at[index, column_name_embedding] = True
                    df.at[index, column_name_embedding_fail] = "no error"
                    print(f"Tensor (at index: {index}) exist already - No copy required : {image_pfad}")
            except Exception as e:
                print(f"Error Image (at index: {index}) copying image {destination_path}: {e}")
        else:
            print(f"Tensor (at index: {index}) not found: {source_path}")


### Test function
# destination_path_update = DESTINATION_PATH + '/' + selected_image_folders[0]
# copy_availabe_embeddings(data_temp, CACHE, destination_path_update, column_name_embedding)

# %%
### Create Tensor for images not exist yet
# Embeddings and tensor are used synonymously

def image_to_tensor(
    index: int,
    df: pd.DataFrame,
    model: object,
    transform: object,
    source_dir: str,
    destination_dir: str,
    column_name_embedding: str,
    column_name_embedding_fail: str
):

    if not df.at[index, column_name_embedding]:
        try:
            # load image from source
            image_path = df.at[index, "image_path"]
            source_path = os.path.join(source_dir, image_path)
            image = Image.open(source_path).convert("RGB")

            # transform image to tensor (embeddings)
            image_transformed = transform(image)
            image_transformed = image_transformed.unsqueeze(0).to(device)
            tensor = model(image_transformed)

            # save tensor to destination
            tensor_path = change_file_extension_to_pt(image_path)
            destination_path = os.path.join(destination_dir, tensor_path)
            os.makedirs(os.path.dirname(destination_path), exist_ok=True)
            torch.save(tensor, destination_path)

            # save info into dataFrame
            df.at[index, column_name_embedding] = True
            df.at[index, column_name_embedding_fail] = "no error"
            print(f"Tensor (at index: {index}) created and saved: {destination_path}")
        except Exception as e:
            df.at[index, column_name_embedding_fail] = f'{e}'
            print(f"Error Image (at index: {index}) by creating tensor {image_path}: {e}")
    else:
        print(f"Tensor (at index: {index}) already exists: {df.at[index, 'image_path']}")


### Test function
# destination_path_update = DESTINATION_PATH + '/' + selected_image_folders[0]
# source_dir_update = IMAGE_FOLDER_PATH + '/' + selected_image_folders[0]
# image_to_tensor(0, data_temp, dinov2_vits14, transform, source_dir_update, destination_path_update, "tensor_created")

# %%
### Execute download_image function with ThreadPoolExecutor

def image_to_tensor_with_executorpool(
    max_workers: int,
    image_to_tensor: callable,
    df: pd.DataFrame,
    model: object,
    transform: object,
    source_dir: str,
    destination_dir: str,
    column_name_embedding: str,
    column_name_embedding_fail: str
):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        for index in df.index:
            if len(futures) > 50:
                for future in as_completed(futures):
                    try:
                        future.result()
                    except Exception as e:
                        print(f"Error while retreving result from future: {e}")
                futures = []

            future = executor.submit(
                image_to_tensor,
                index,
                df,
                model,
                transform,
                source_dir,
                destination_dir,
                column_name_embedding,
                column_name_embedding_fail
            )
            futures.append(future)


### Test function
# destination_path_update = DESTINATION_PATH + '/' + selected_image_folders[0]
# source_dir_update = IMAGE_FOLDER_PATH + '/' + selected_image_folders[0]
# image_to_tensor_with_executorpool(MAX_WORKERS, image_to_tensor, data_temp, dinov2_vits14, transform, source_dir_update, destination_path_update, column_name_embedding)

# %%
### RUN - call functions to process file
def process_file(
    csv_load_dir: str,
    csv_save_dir: str,
    model: object,
    transform: object,
    image_source_dir: str,
    embedding_destination_dir: str,
    CACHE: str,
    MAX_WORKERS: int,
):
    print(f"Processing CSV file from: {csv_load_dir}")
    print(f"Saving CSV file to: {csv_save_dir}")
    print(f"Source folder: {image_source_dir}")
    print(f"Destination folder: {embedding_destination_dir}")
    print(f"Cache folder: {CACHE}")
    print("--------------------------------------")

    # process file
    print(">>> Load data and add column to track existing tensors")
    df = load_data(csv_load_dir)
    column_name_embeddings, column_name_embedding_fail = add_embedding_column_to_df(df)

    print(">>> Starting copy availabe tensors from cache to destination")
    copy_availabe_embeddings(
        df, CACHE, embedding_destination_dir, column_name_embeddings, column_name_embedding_fail
    )

    print(f">>> Starting creating tensors with {MAX_WORKERS} workers")
    image_to_tensor_with_executorpool(
        MAX_WORKERS,
        image_to_tensor,
        df,
        model,
        transform,
        image_source_dir,
        embedding_destination_dir,
        column_name_embeddings,
        column_name_embedding_fail
    )

    print(f">>> Save updated Dataframe to: {csv_save_dir}")
    df.to_csv(csv_save_dir, na_rep="NULL", index=False)

    # print(">>> Copy files to cache if not available")
    # subprocess.run(f'rsync -av --ignore-existing {embedding_destination_dir + "/"} {CACHE}', shell=True, check=True)
    # !rsync -av --ignore-existing {DESTINATION} {CACHE}

    print(f">>> FINISH Process: {csv_filename}\n\n")


### call funktions

# matching selected csv file with image folders
for csv_filename in selected_csv_files:

    csv_load_path = os.path.join(CSV_SOURCE_FOLDER_PATH, csv_filename)
    csv_save_path = os.path.join(CSV_DESTINATION_FOLDER_PATH, csv_filename)

    process_file(
        csv_load_path,
        csv_save_path,
        dinov2_vits14,
        transform,
        IMAGE_FOLDER_PATH,
        DESTINATION_PATH,
        CACHE,
        MAX_WORKERS,
    )
# Out:
# Processing CSV file from: /home/jleick/masterArbeitProjekt/final_release/data/datasets/created/high_id_train.csv
# Saving CSV file to: /home/jleick/masterArbeitProjekt/final_release/data/datasets/created/embedding_created_copied/high_id_train.csv
# Source folder: /home/jleick/masterArbeitProjekt/final_release/data/images/copied/high
# Destination folder: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high
# Cache folder: /home/
# --------------------------------------
# >>> Load data and add column to track existing tensors
# >>> (85803, 19) - Added column: embedding_created
# >>> (85803, 20) - Added column: embedding_created_fail
# >>> Starting copy availabe tensors from cache to destination
# Tensor (at index: 0) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1024198246.pt
# Tensor (at index: 1) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1024215304.pt
# Tensor (at index: 2) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1052571037.pt
# Tensor (at index: 3) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1065577692.pt
# Tensor (at index: 4) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1065580693.pt
# Tensor (at index: 5) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1092890604.pt
# Tensor (at index: 6) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1092890604_1.pt
# Tensor (at index: 7) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1262367262.pt
# Tensor (at index: 8) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1265573687.pt
# Tensor (at index: 9) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1265573687_1.pt
# Tensor (at index: 10) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1269543173.pt
# Tensor (at index: 11) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1269545612.pt
# Tensor (at index: 12) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1270049069.pt
# Tensor (at index: 13) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1270055675.pt
# Tensor (at index: 14) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1272091135.pt
# Tensor (at index: 15) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1272104955.pt
# Tensor (at index: 16) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1272112929.pt
# Tensor (at index: 17) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1272117528.pt
# Tensor (at index: 18) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291067131.pt
# Tensor (at index: 19) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291067339.pt
# Tensor (at index: 20) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291081469.pt
# Tensor (at index: 21) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291118797.pt
# Tensor (at index: 22) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291669827.pt
# Tensor (at index: 23) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291670898.pt
# Tensor (at index: 24) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291679281.pt
# Tensor (at index: 25) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291680950.pt
# Tensor (at index: 26) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1291680950_1.pt
# Tensor (at index: 27) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1305111097.pt
# Tensor (at index: 28) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1305136513.pt
# Tensor (at index: 29) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1305165552.pt
# Tensor (at index: 30) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1305175646.pt
# Tensor (at index: 31) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1323011577.pt
# Tensor (at index: 32) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453182572.pt
# Tensor (at index: 33) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453250053.pt
# Tensor (at index: 34) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453253181.pt
# Tensor (at index: 35) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453257709.pt
# Tensor (at index: 36) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453273391.pt
# Tensor (at index: 37) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453287030.pt
# Tensor (at index: 38) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453341971.pt
# Tensor (at index: 39) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453378138.pt
# Tensor (at index: 40) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453422354.pt
# Tensor (at index: 41) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453422354_1.pt
# Tensor (at index: 42) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453507940.pt
# Tensor (at index: 43) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453522169.pt
# Tensor (at index: 44) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1453527448.pt
# Tensor (at index: 45) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1455576468.pt
# Tensor (at index: 46) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1455576495.pt
# Tensor (at index: 47) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1457588727.pt
# Tensor (at index: 48) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1500335822.pt
# Tensor (at index: 49) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1562945786.pt
# Tensor (at index: 50) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1562945786_1.pt
# Tensor (at index: 51) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1572360834.pt
# Tensor (at index: 52) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1572385085.pt
# Tensor (at index: 53) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1580504057.pt
# Tensor (at index: 54) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1584402953.pt
# Tensor (at index: 55) not found: /home/9b12d595-11ea-4128-88ea-ed378eb9ea9a/1585227768.pt
# Tensor (at index: 56) not found: /home/9b12d595-11ea-4128-88ea-ed378eb9ea9a/1585229914.pt
# Tensor (at index: 57) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586098859.pt
# Tensor (at index: 58) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586098859_1.pt
# Tensor (at index: 59) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586101642.pt
# Tensor (at index: 60) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586109716.pt
# Tensor (at index: 61) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586111173.pt
# Tensor (at index: 62) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586125213.pt
# Tensor (at index: 63) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586139380.pt
# Tensor (at index: 64) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586915522.pt
# Tensor (at index: 65) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586917354.pt
# Tensor (at index: 66) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586918353.pt
# Tensor (at index: 67) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586920080.pt
# Tensor (at index: 68) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586920080_1.pt
# Tensor (at index: 69) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586920080_2.pt
# Tensor (at index: 70) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586920797.pt
# Tensor (at index: 71) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586922411.pt
# Tensor (at index: 72) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586922709.pt
# Tensor (at index: 73) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586948175.pt
# Tensor (at index: 74) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586948175_1.pt
# Tensor (at index: 75) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586954475.pt
# Tensor (at index: 76) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1586955041.pt
# Tensor (at index: 77) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621770054.pt
# Tensor (at index: 78) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621770720.pt
# Tensor (at index: 79) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621772566.pt
# Tensor (at index: 80) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621773533.pt
# Tensor (at index: 81) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621774046.pt
# Tensor (at index: 82) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621776639.pt
# Tensor (at index: 83) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621795368.pt
# Tensor (at index: 84) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621801522.pt
# Tensor (at index: 85) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621801522_1.pt
# Tensor (at index: 86) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1621803390.pt
# Tensor (at index: 87) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1640027120.pt
# Tensor (at index: 88) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1640039938.pt
# Tensor (at index: 89) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1640062027_2.pt
# Tensor (at index: 90) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1640074961.pt
# Tensor (at index: 91) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1640084406.pt
# Tensor (at index: 92) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1640090157.pt
# Tensor (at index: 93) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1640091485_4.pt
# Tensor (at index: 94) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1703133876.pt
# Tensor (at index: 95) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1703212878.pt
# Tensor (at index: 96) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1802628517.pt
# Tensor (at index: 97) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1806329606.pt
# Tensor (at index: 98) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1806329606_1.pt
# Tensor (at index: 99) not found: /home/0108bdc9-3d7f-459a-a92e-a40c3ed07c93/1822280406.pt
# Tensor (at index: 100) not found: /home/0108bdc9-3d7f-459a-a92e-a40c3ed07c93/1822280406_1.pt
# Tensor (at index: 101) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1831142950.pt
# Tensor (at index: 102) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1831145263.pt
# Tensor (at index: 103) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1831234485.pt
# Tensor (at index: 104) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1836620081.pt
# Tensor (at index: 105) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1836693667.pt
# Tensor (at index: 106) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1837077127.pt
# Tensor (at index: 107) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1837077127_1.pt
# Tensor (at index: 108) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1837080385.pt
# Tensor (at index: 109) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1837080385_1.pt
# Tensor (at index: 110) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1838007466.pt
# Tensor (at index: 111) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1838022630.pt
# Tensor (at index: 112) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1838305528.pt
# Tensor (at index: 113) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1838305528_1.pt
# Tensor (at index: 114) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1838307468.pt
# Tensor (at index: 115) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1838307468_1.pt
# Tensor (at index: 116) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1838307468_2.pt
# Tensor (at index: 117) not found: /home/9b12d595-11ea-4128-88ea-ed378eb9ea9a/1838878901.pt
# Tensor (at index: 118) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1839277716.pt
# Tensor (at index: 119) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1839278607.pt
# Tensor (at index: 120) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1841329730.pt
# Tensor (at index: 121) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1841329730_6.pt
# Tensor (at index: 122) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846749127.pt
# Tensor (at index: 123) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846749203.pt
# Tensor (at index: 124) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846816028.pt
# Tensor (at index: 125) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846816046.pt
# Tensor (at index: 126) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846816055.pt
# Tensor (at index: 127) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846816073.pt
# Tensor (at index: 128) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846816087.pt
# Tensor (at index: 129) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846816131.pt
# Tensor (at index: 130) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846822512.pt
# Tensor (at index: 131) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846822602.pt
# Tensor (at index: 132) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847565.pt
# Tensor (at index: 133) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847592.pt
# Tensor (at index: 134) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847623.pt
# Tensor (at index: 135) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847628.pt
# Tensor (at index: 136) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847637.pt
# Tensor (at index: 137) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847641.pt
# Tensor (at index: 138) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847650.pt
# Tensor (at index: 139) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847687.pt
# Tensor (at index: 140) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847704.pt
# Tensor (at index: 141) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847709.pt
# Tensor (at index: 142) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846847768.pt
# Tensor (at index: 143) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861041.pt
# Tensor (at index: 144) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861055.pt
# Tensor (at index: 145) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861064.pt
# Tensor (at index: 146) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861073.pt
# Tensor (at index: 147) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861078.pt
# Tensor (at index: 148) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861082.pt
# Tensor (at index: 149) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861087.pt
# Tensor (at index: 150) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861091.pt
# Tensor (at index: 151) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861113.pt
# Tensor (at index: 152) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861118.pt
# Tensor (at index: 153) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861122.pt
# Tensor (at index: 154) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846861136.pt
# Tensor (at index: 155) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846956799.pt
# Tensor (at index: 156) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846956843.pt
# Tensor (at index: 157) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846961103.pt
# Tensor (at index: 158) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846961108.pt
# Tensor (at index: 159) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846967936.pt
# Tensor (at index: 160) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846967940.pt
# Tensor (at index: 161) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846967963.pt
# Tensor (at index: 162) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846967968.pt
# Tensor (at index: 163) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846967972.pt
# Tensor (at index: 164) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846967977.pt
# Tensor (at index: 165) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846967981.pt
# Tensor (at index: 166) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846967986.pt
# Tensor (at index: 167) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846968016.pt
# Tensor (at index: 168) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846968020.pt
# Tensor (at index: 169) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846968025.pt
# Tensor (at index: 170) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846968039.pt
# Tensor (at index: 171) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846968066.pt
# Tensor (at index: 172) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846969830.pt
# Tensor (at index: 173) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846969853.pt
# Tensor (at index: 174) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846969858.pt
# Tensor (at index: 175) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846969867.pt
# Tensor (at index: 176) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846969876.pt
# Tensor (at index: 177) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846969885.pt
# Tensor (at index: 178) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846969907.pt
# Tensor (at index: 179) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973696.pt
# Tensor (at index: 180) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973709.pt
# Tensor (at index: 181) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973713.pt
# Tensor (at index: 182) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973718.pt
# Tensor (at index: 183) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973722.pt
# Tensor (at index: 184) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973731.pt
# Tensor (at index: 185) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973736.pt
# Tensor (at index: 186) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973740.pt
# Tensor (at index: 187) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973745.pt
# Tensor (at index: 188) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846973759.pt
# Tensor (at index: 189) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984540.pt
# Tensor (at index: 190) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984545.pt
# Tensor (at index: 191) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984554.pt
# Tensor (at index: 192) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984559.pt
# Tensor (at index: 193) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984563.pt
# Tensor (at index: 194) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984568.pt
# Tensor (at index: 195) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984572.pt
# Tensor (at index: 196) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984581.pt
# Tensor (at index: 197) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984603.pt
# Tensor (at index: 198) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984621.pt
# Tensor (at index: 199) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846984649.pt
# Tensor (at index: 200) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846996975.pt
# Tensor (at index: 201) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846998775.pt
# Tensor (at index: 202) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1846999751.pt
# Tensor (at index: 203) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847019464.pt
# Tensor (at index: 204) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847037144.pt
# Tensor (at index: 205) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847053501.pt
# Tensor (at index: 206) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847053560.pt
# Tensor (at index: 207) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847053655.pt
# Tensor (at index: 208) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847053669.pt
# Tensor (at index: 209) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847053704.pt
# Tensor (at index: 210) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847053817.pt
# Tensor (at index: 211) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847062687.pt
# Tensor (at index: 212) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847105206.pt
# Tensor (at index: 213) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847105229.pt
# Tensor (at index: 214) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847107047.pt
# Tensor (at index: 215) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847124958.pt
# Tensor (at index: 216) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128201.pt
# Tensor (at index: 217) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128229.pt
# Tensor (at index: 218) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128238.pt
# Tensor (at index: 219) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128242.pt
# Tensor (at index: 220) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128247.pt
# Tensor (at index: 221) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128251.pt
# Tensor (at index: 222) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128274.pt
# Tensor (at index: 223) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128300.pt
# Tensor (at index: 224) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128963.pt
# Tensor (at index: 225) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128977.pt
# Tensor (at index: 226) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847128990.pt
# Tensor (at index: 227) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847129002.pt
# Tensor (at index: 228) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847129007.pt
# Tensor (at index: 229) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847129016.pt
# Tensor (at index: 230) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249737.pt
# Tensor (at index: 231) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249746.pt
# Tensor (at index: 232) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249773.pt
# Tensor (at index: 233) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249782.pt
# Tensor (at index: 234) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249787.pt
# Tensor (at index: 235) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249791.pt
# Tensor (at index: 236) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249796.pt
# Tensor (at index: 237) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249809.pt
# Tensor (at index: 238) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847249822.pt
# Tensor (at index: 239) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250519.pt
# Tensor (at index: 240) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250528.pt
# Tensor (at index: 241) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250550.pt
# Tensor (at index: 242) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250564.pt
# Tensor (at index: 243) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250573.pt
# Tensor (at index: 244) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250582.pt
# Tensor (at index: 245) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250591.pt
# Tensor (at index: 246) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250596.pt
# Tensor (at index: 247) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250604.pt
# Tensor (at index: 248) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250609.pt
# Tensor (at index: 249) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250622.pt
# Tensor (at index: 250) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250631.pt
# Tensor (at index: 251) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/1847250640.pt
# Tensor (at index: 252) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1847443808.pt
# Tensor (at index: 253) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1847642956.pt
# Tensor (at index: 254) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1848772997.pt
# Tensor (at index: 255) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1848776709.pt
# Tensor (at index: 256) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1848801237.pt
# Tensor (at index: 257) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1850915508.pt
# Tensor (at index: 258) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1850946482.pt
# Tensor (at index: 259) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1850953056.pt
# Tensor (at index: 260) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1850956747.pt
# Tensor (at index: 261) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1850958367.pt
# Tensor (at index: 262) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1850958367_1.pt
# Tensor (at index: 263) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1850968398.pt
# Tensor (at index: 264) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880542125.pt
# Tensor (at index: 265) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880546397.pt
# Tensor (at index: 266) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880552827.pt
# Tensor (at index: 267) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880581041_2.pt
# Tensor (at index: 268) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880594272.pt
# Tensor (at index: 269) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880598679_3.pt
# Tensor (at index: 270) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880598679_5.pt
# Tensor (at index: 271) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880606584.pt
# Tensor (at index: 272) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1880627946_1.pt
# Tensor (at index: 273) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1883562196.pt
# Tensor (at index: 274) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1883966233.pt
# Tensor (at index: 275) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1883969280.pt
# Tensor (at index: 276) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1883969280_1.pt
# Tensor (at index: 277) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1890032507.pt
# Tensor (at index: 278) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1890082313.pt
# Tensor (at index: 279) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1898790840.pt
# Tensor (at index: 280) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1898813948.pt
# Tensor (at index: 281) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1898835656.pt
# Tensor (at index: 282) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1899777619.pt
# Tensor (at index: 283) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1899777619_1.pt
# Tensor (at index: 284) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1901077768.pt
# Tensor (at index: 285) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1913663644.pt
# Tensor (at index: 286) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1913682918.pt
# Tensor (at index: 287) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1913711393.pt
# Tensor (at index: 288) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1914201005.pt
# Tensor (at index: 289) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1914317994.pt
# Tensor (at index: 290) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1920795193.pt
# Tensor (at index: 291) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1931480199.pt
# Tensor (at index: 292) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1931520478.pt
# Tensor (at index: 293) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1932336042_1.pt
# Tensor (at index: 294) not found: /home/76525e81-9210-401d-a90d-5509f771c0e7/1932623700.pt
# Tensor (at index: 295) not found: /home/76525e81-9210-401d-a90d-5509f771c0e7/1932680423.pt
# Tensor (at index: 296) not found: /home/76525e81-9210-401d-a90d-5509f771c0e7/1932680432.pt
# Tensor (at index: 297) not found: /home/76525e81-9210-401d-a90d-5509f771c0e7/1932681364.pt
# Tensor (at index: 298) not found: /home/76525e81-9210-401d-a90d-5509f771c0e7/1932681373.pt
# Tensor (at index: 299) not found: /home/76525e81-9210-401d-a90d-5509f771c0e7/1932757644.pt
# Tensor (at index: 300) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1933570311.pt
# Tensor (at index: 301) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1935599933.pt
# Tensor (at index: 302) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1935601952.pt
# Tensor (at index: 303) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1944375504.pt
# Tensor (at index: 304) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1945417545.pt
# Tensor (at index: 305) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1945419926.pt
# Tensor (at index: 306) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1946197602.pt
# Tensor (at index: 307) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1978464682.pt
# Tensor (at index: 308) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1986501394.pt
# Tensor (at index: 309) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1986616211.pt
# Tensor (at index: 310) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1990446003.pt
# Tensor (at index: 311) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1990448425.pt
# Tensor (at index: 312) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1990448894.pt
# Tensor (at index: 313) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1990515371.pt
# Tensor (at index: 314) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1990528214.pt
# Tensor (at index: 315) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1990617878.pt
# Tensor (at index: 316) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/1990632416.pt
# Tensor (at index: 317) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2005326578.pt
# Tensor (at index: 318) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2005333282.pt
# Tensor (at index: 319) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2005367118.pt
# Tensor (at index: 320) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2005367523.pt
# Tensor (at index: 321) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2012948139.pt
# Tensor (at index: 322) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2012948797.pt
# Tensor (at index: 323) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2012948797_1.pt
# Tensor (at index: 324) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2013019724.pt
# Tensor (at index: 325) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2013019724_1.pt
# Tensor (at index: 326) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2013691539.pt
# Tensor (at index: 327) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2013721369.pt
# Tensor (at index: 328) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2013734432.pt
# Tensor (at index: 329) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2028441008.pt
# Tensor (at index: 330) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2028497016_1.pt
# Tensor (at index: 331) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2028519610.pt
# Tensor (at index: 332) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2028519610_1.pt
# Tensor (at index: 333) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2235522385.pt
# Tensor (at index: 334) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2236241971.pt
# Tensor (at index: 335) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2236241971_1.pt
# Tensor (at index: 336) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2236267563.pt
# Tensor (at index: 337) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2236824613.pt
# Tensor (at index: 338) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2236824695.pt
# Tensor (at index: 339) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2236863633.pt
# Tensor (at index: 340) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2237460268.pt
# Tensor (at index: 341) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2238888736.pt
# Tensor (at index: 342) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2238985670.pt
# Tensor (at index: 343) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2239011412.pt
# Tensor (at index: 344) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2239058187.pt
# Tensor (at index: 345) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2242899829.pt
# Tensor (at index: 346) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2242899829_1.pt
# Tensor (at index: 347) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2242965208.pt
# Tensor (at index: 348) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2244253308.pt
# Tensor (at index: 349) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2251817797.pt
# Tensor (at index: 350) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2251819551.pt
# Tensor (at index: 351) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2251820090.pt
# Tensor (at index: 352) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2251917309.pt
# Tensor (at index: 353) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2251993283.pt
# Tensor (at index: 354) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2251993305.pt
# Tensor (at index: 355) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2252005224.pt
# Tensor (at index: 356) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2265822662.pt
# Tensor (at index: 357) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2265826465.pt
# Tensor (at index: 358) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2265826465_1.pt
# Tensor (at index: 359) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2265826492.pt
# Tensor (at index: 360) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2265826492_1.pt
# Tensor (at index: 361) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2265837413.pt
# Tensor (at index: 362) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2265842200.pt
# Tensor (at index: 363) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2265867942.pt
# Tensor (at index: 364) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2269269745.pt
# Tensor (at index: 365) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2269269745_1.pt
# Tensor (at index: 366) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2269297055.pt
# Tensor (at index: 367) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2269324865.pt
# Tensor (at index: 368) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2269324865_1.pt
# Tensor (at index: 369) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2269324865_2.pt
# Tensor (at index: 370) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2269328172.pt
# Tensor (at index: 371) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273196412.pt
# Tensor (at index: 372) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273220590.pt
# Tensor (at index: 373) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273220590_1.pt
# Tensor (at index: 374) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273220590_2.pt
# Tensor (at index: 375) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273220590_3.pt
# Tensor (at index: 376) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273226616.pt
# Tensor (at index: 377) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273226616_1.pt
# Tensor (at index: 378) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273230689.pt
# Tensor (at index: 379) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273236070.pt
# Tensor (at index: 380) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273236958.pt
# Tensor (at index: 381) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273236958_1.pt
# Tensor (at index: 382) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273253927.pt
# Tensor (at index: 383) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273257914.pt
# Tensor (at index: 384) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273261581.pt
# Tensor (at index: 385) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273266716.pt
# Tensor (at index: 386) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273288627.pt
# Tensor (at index: 387) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273290980.pt
# Tensor (at index: 388) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273290980_1.pt
# Tensor (at index: 389) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2273315964.pt
# Tensor (at index: 390) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283040705.pt
# Tensor (at index: 391) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283045890.pt
# Tensor (at index: 392) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283048329.pt
# Tensor (at index: 393) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283061392.pt
# Tensor (at index: 394) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283078574.pt
# Tensor (at index: 395) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283084202.pt
# Tensor (at index: 396) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283103002.pt
# Tensor (at index: 397) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283110009_1.pt
# Tensor (at index: 398) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283120841.pt
# Tensor (at index: 399) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283128177.pt
# Tensor (at index: 400) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283142522.pt
# Tensor (at index: 401) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283147428.pt
# Tensor (at index: 402) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283235344.pt
# Tensor (at index: 403) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283257877.pt
# Tensor (at index: 404) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2283270417.pt
# Tensor (at index: 405) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294399151.pt
# Tensor (at index: 406) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294423720.pt
# Tensor (at index: 407) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294439232.pt
# Tensor (at index: 408) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294446860.pt
# Tensor (at index: 409) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294461930.pt
# Tensor (at index: 410) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294521299.pt
# Tensor (at index: 411) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294536428.pt
# Tensor (at index: 412) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294630900.pt
# Tensor (at index: 413) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2294637615.pt
# Tensor (at index: 414) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311274002.pt
# Tensor (at index: 415) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311274002_1.pt
# Tensor (at index: 416) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311274886.pt
# Tensor (at index: 417) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311311037.pt
# Tensor (at index: 418) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311311037_1.pt
# Tensor (at index: 419) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311311037_2.pt
# Tensor (at index: 420) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311323719.pt
# Tensor (at index: 421) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311330482.pt
# Tensor (at index: 422) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311330482_1.pt
# Tensor (at index: 423) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311368819.pt
# Tensor (at index: 424) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311383164.pt
# Tensor (at index: 425) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311385072.pt
# Tensor (at index: 426) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2311420194.pt
# Tensor (at index: 427) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2331861337.pt
# Tensor (at index: 428) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2331892815.pt
# Tensor (at index: 429) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2331905027.pt
# Tensor (at index: 430) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2331905027_1.pt
# Tensor (at index: 431) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2331960873.pt
# Tensor (at index: 432) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2350360295_1.pt
# Tensor (at index: 433) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2350390274.pt
# Tensor (at index: 434) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2350412788.pt
# Tensor (at index: 435) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2350433749.pt
# Tensor (at index: 436) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2366038223.pt
# Tensor (at index: 437) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2366038223_1.pt
# Tensor (at index: 438) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2397480595.pt
# Tensor (at index: 439) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2397488506.pt
# Tensor (at index: 440) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2397494275.pt
# Tensor (at index: 441) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2397634139.pt
# Tensor (at index: 442) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2422858952.pt
# Tensor (at index: 443) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2422862704.pt
# Tensor (at index: 444) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2422862704_1.pt
# Tensor (at index: 445) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2422888454.pt
# Tensor (at index: 446) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2423117395.pt
# Tensor (at index: 447) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2429349792.pt
# Tensor (at index: 448) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2429449494.pt
# Tensor (at index: 449) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2429449494_1.pt
# Tensor (at index: 450) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2429593156.pt
# Tensor (at index: 451) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2444976345.pt
# Tensor (at index: 452) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2444978311.pt
# Tensor (at index: 453) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2444980471.pt
# Tensor (at index: 454) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2444994336.pt
# Tensor (at index: 455) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2445025371.pt
# Tensor (at index: 456) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2445037346.pt
# Tensor (at index: 457) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2445060449.pt
# Tensor (at index: 458) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2445062320.pt
# Tensor (at index: 459) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2445099339.pt
# Tensor (at index: 460) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2445104341.pt
# Tensor (at index: 461) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2451596617.pt
# Tensor (at index: 462) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2460053700.pt
# Tensor (at index: 463) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2460152782.pt
# Tensor (at index: 464) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2460152782_1.pt
# Tensor (at index: 465) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2460152782_2.pt
# Tensor (at index: 466) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2465140176.pt
# Tensor (at index: 467) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2465175934.pt
# Tensor (at index: 468) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2465175934_1.pt
# Tensor (at index: 469) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2465179575.pt
# Tensor (at index: 470) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2465184916.pt
# Tensor (at index: 471) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2465204422.pt
# Tensor (at index: 472) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2465366504.pt
# Tensor (at index: 473) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2518023674.pt
# Tensor (at index: 474) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2518152275.pt
# Tensor (at index: 475) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542722926.pt
# Tensor (at index: 476) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542723218.pt
# Tensor (at index: 477) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542723376.pt
# Tensor (at index: 478) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542723600.pt
# Tensor (at index: 479) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542737317.pt
# Tensor (at index: 480) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542765244.pt
# Tensor (at index: 481) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542765424.pt
# Tensor (at index: 482) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542768615.pt
# Tensor (at index: 483) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542768624.pt
# Tensor (at index: 484) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542768912.pt
# Tensor (at index: 485) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542769574.pt
# Tensor (at index: 486) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542769628.pt
# Tensor (at index: 487) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542769880.pt
# Tensor (at index: 488) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542782614.pt
# Tensor (at index: 489) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542782713.pt
# Tensor (at index: 490) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542783181.pt
# Tensor (at index: 491) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542783307.pt
# Tensor (at index: 492) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542787655.pt
# Tensor (at index: 493) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542788339.pt
# Tensor (at index: 494) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542788370.pt
# Tensor (at index: 495) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542788519.pt
# Tensor (at index: 496) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542788659.pt
# Tensor (at index: 497) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542789905.pt
# Tensor (at index: 498) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542797447.pt
# Tensor (at index: 499) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542797735.pt
# Tensor (at index: 500) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542797820.pt
# Tensor (at index: 501) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542797893.pt
# Tensor (at index: 502) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542797906.pt
# Tensor (at index: 503) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542807477.pt
# Tensor (at index: 504) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542807544.pt
# Tensor (at index: 505) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542807715.pt
# Tensor (at index: 506) not found: /home/cca13f2c-0d2c-4c2f-93b9-4446c0cc1629/2542807729.pt
# Tensor (at index: 507) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2543055962.pt
# Tensor (at index: 508) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2543076009.pt
# Tensor (at index: 509) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2549979424.pt
# Tensor (at index: 510) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2550105185.pt
# Tensor (at index: 511) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2550135173.pt
# Tensor (at index: 512) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2550164310.pt
# Tensor (at index: 513) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2563447427.pt
# Tensor (at index: 514) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2563447832.pt
# Tensor (at index: 515) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2563457340.pt
# Tensor (at index: 516) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2563466818.pt
# Tensor (at index: 517) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2563466818_1.pt
# Tensor (at index: 518) not found: /home/50c9509d-22c7-4a22-a47d-8c48425ef4a7/2563621333.pt
# ...
# Tensor (at index: 992) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325533583.pt
# Tensor (at index: 1006) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327678980.pt
# Tensor (at index: 1002) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325820872.pt
# Tensor (at index: 980) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3320886978.pt
# Tensor (at index: 995) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325542353.pt
# Tensor (at index: 1003) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325822983.pt
# Tensor (at index: 1001) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325800365.pt
# Tensor (at index: 1005) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325917474_2.pt
# Tensor (at index: 1008) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327753274.pt
# Tensor (at index: 1012) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327771166.ptTensor (at index: 996) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325542682_1.pt
#
# Tensor (at index: 997) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325561361.pt
# Tensor (at index: 998) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325564818.pt
# Tensor (at index: 1004) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325823270.pt
# Tensor (at index: 1009) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327769899.pt
# Tensor (at index: 1011) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327769899_2.pt
# Tensor (at index: 1019) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330773719_1.pt
# Tensor (at index: 1018) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330773719.pt
# Tensor (at index: 1007) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327702941.pt
# Tensor (at index: 1014) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327936654.pt
# Tensor (at index: 973) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3314434252.pt
# Tensor (at index: 1000) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3325684293.pt
# Tensor (at index: 1010) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327769899_1.pt
# Tensor (at index: 1013) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3327915378.pt
# Tensor (at index: 1016) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330489977.pt
# Tensor (at index: 1015) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330457161.pt
# Tensor (at index: 1017) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330497838.pt
# Tensor (at index: 1037) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335487380.pt
# Tensor (at index: 1025) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3333048214_1.pt
# Tensor (at index: 1024) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3333048214.pt
# Tensor (at index: 1038) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335487380_1.pt
# Tensor (at index: 1032) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335215354.pt
# Tensor (at index: 1029) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3333390908.pt
# Tensor (at index: 1033) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335393082.pt
# Tensor (at index: 1039) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335487380_2.pt
# Tensor (at index: 1023) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330908520_1.pt
# Tensor (at index: 1040) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335487380_3.pt
# Tensor (at index: 1034) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335393564.pt
# Tensor (at index: 1036) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335416824.pt
# Tensor (at index: 1020) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330837349.pt
# Tensor (at index: 1022) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330908520.pt
# Tensor (at index: 1031) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335102827_1.ptTensor (at index: 1026) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3333157407.pt
#
# Tensor (at index: 1028) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3333315276.pt
# Tensor (at index: 1030) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335102827.pt
# Tensor (at index: 1048) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337774936.pt
# Tensor (at index: 1035) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3335410578.pt
# Tensor (at index: 1044) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337562427.pt
# Tensor (at index: 1042) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337444892.pt
# Tensor (at index: 1049) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337785961.pt
# Tensor (at index: 1050) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337812235.pt
# Tensor (at index: 1046) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337736587_1.pt
# Tensor (at index: 1043) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337444892_1.pt
# Tensor (at index: 1051) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337816303.pt
# Tensor (at index: 1021) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3330876594.pt
# Tensor (at index: 1027) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3333157407_1.pt
# Tensor (at index: 1052) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337940341.pt
# Tensor (at index: 1055) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3338128315.pt
# Tensor (at index: 1045) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337736587.pt
# Tensor (at index: 1056) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3338128315_1.pt
# Tensor (at index: 1054) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3338002599.pt
# Tensor (at index: 1053) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337991223.pt
# Tensor (at index: 1057) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3338156486.pt
# Tensor (at index: 1041) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337433614.pt
# Tensor (at index: 1058) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3338156486_1.pt
# Tensor (at index: 1059) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3338156486_2.pt
# Tensor (at index: 1047) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3337763163.pt
# Tensor (at index: 1062) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3343837725.pt
# Tensor (at index: 1063) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3343839160.pt
# Tensor (at index: 1065) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3344059638.pt
# Tensor (at index: 1060) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3343750997.pt
# Tensor (at index: 1066) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3344098379.pt
# Tensor (at index: 1061) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3343750997_3.pt
# Tensor (at index: 1067) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3355417914.pt
# Tensor (at index: 1068) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3355417914_1.pt
# Tensor (at index: 1064) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3343928594.pt
# Tensor (at index: 1070) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3355473737_1.pt
# Tensor (at index: 1069) created and saved: /home/jleick/masterArbeitProjekt/final_release/data/embeddings/copied/high/50c9509d-22c7-4a22-a47d-8c48425ef4a7/3355473737.pt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 60
#      57 csv_load_path = os.path.join(CSV_SOURCE_FOLDER_PATH, csv_filename)
#      58 csv_save_path = os.path.join(CSV_DESTINATION_FOLDER_PATH, csv_filename)
# ---> 60 process_file(
#      61     csv_load_path,
#      62     csv_save_path,
#      63     dinov2_vits14,
#      64     transform,
#      65     IMAGE_FOLDER_PATH,
#      66     DESTINATION_PATH,
#      67     CACHE,
#      68     MAX_WORKERS,
#      69 )
#
# Cell In[21], line 30, in process_file(csv_load_dir, csv_save_dir, model, transform, image_source_dir, embedding_destination_dir, CACHE, MAX_WORKERS)
#      25 copy_availabe_embeddings(
#      26     df, CACHE, embedding_destination_dir, column_name_embeddings, column_name_embedding_fail
#      27 )
#      29 print(f">>> Starting creating tensors with {MAX_WORKERS} workers")
# ---> 30 image_to_tensor_with_executorpool(
#      31     MAX_WORKERS,
#      32     image_to_tensor,
#      33     df,
#      34     model,
#      35     transform,
#      36     image_source_dir,
#      37     embedding_destination_dir,
#      38     column_name_embeddings,
#      39     column_name_embedding_fail
#      40 )
#      42 print(f">>> Save updated Dataframe to: {csv_save_dir}")
#      43 df.to_csv(csv_save_dir, na_rep="NULL", index=False)
#
# Cell In[20], line 18, in image_to_tensor_with_executorpool(max_workers, image_to_tensor, df, model, transform, source_dir, destination_dir, column_name_embedding, column_name_embedding_fail)
#      16 for index in df.index:
#      17     if len(futures) > 50:
# ---> 18         for future in as_completed(futures):
#      19             try:
#      20                 future.result()
#
# File ~/miniconda3/envs/masterArbeit/lib/python3.12/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File ~/miniconda3/envs/masterArbeit/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/envs/masterArbeit/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
